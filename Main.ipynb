# %%
from sympy import *
from random import randint
# %run Geom_Prolongation.ipynb
# %run Particular_Distributions.ipynb

# %%
g=Symp_symb(7)
E=g.ext_alg
C=g.cochain_complex
D=Free_distr_Jacobi_7(g)
P=Geom_Prolongation(D)

# %%
y,h,e=symbols('y,h,e')
yn,hn,en=symbols('yn,hn,en')
K=IndexedBase('K')
Y,H,E,X,e1,e2,e3,e4,e5,e6,N=g.basis
p1_subs_dict={e:e+en,h:h+hn,y:exp(2*hn)*y+yn}
p1_inv=-exp(-2*hn)*yn*Y-hn*H-en*E
yn,hn,en=symbols('yn,hn,en')
p1_subs_dict={e:e+en,h:h+hn,y:exp(2*hn)*y+yn}
p1_inv=-exp(-2*hn)*yn*Y-hn*H-en*E

def check_equivar(c):
    r=c.subs(p1_subs_dict)-p1_inv.Ad(c)
    simplify_cochain(r)
    if r==C.elt({}): return True
    else: return r

# %%
F1,K1=P.normal_frame(1)
F2,K2=P.normal_frame(2)
# Out:
# weight 1 curvature computed in time 1.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 5.0 sec
# weight 1 normalization complete in time 6.0 sec
# weight 2 curvature computed in time 2.0 min 40.0 sec
# weight 2 projection computed in time 1.0 sec
# weight 2 preimage cochain computed in time 3.0 sec
# weight 2 Matrix exponential complete in time 16.0 sec
# weight 2 normalization complete in time 2.0 min 60.0 sec

# %%
simplify_cochain(K1)
print('K1 =',K1)
simplify_cochain(K2)
print('K2 =',K2)
# Out:
# K1 = 0
# K2 = 0
