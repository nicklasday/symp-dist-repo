# %%
from sympy import *
from random import randint
# %run Geom_Prolongation.ipynb
# %run Particular_Distributions.ipynb

# %%
g=Symp_symb(7)
E=g.ext_alg
C=g.cochain_complex
D,D_JS=Prenorm_distr_Jacobi_7(g,6)
P=Geom_Prolongation(D)

# %%
y,h,e=symbols('y,h,e')
yn,hn,en=symbols('yn,hn,en')
K=IndexedBase('K')
Y,H,E,X,e1,e2,e3,e4,e5,e6,N=g.basis
p1_subs_dict={e:e+en,h:h+hn,y:exp(2*hn)*y+yn}
p1_inv=-exp(-2*hn)*yn*Y-hn*H-en*E
yn,hn,en=symbols('yn,hn,en')
p1_subs_dict={e:e+en,h:h+hn,y:exp(2*hn)*y+yn}
p1_inv=-exp(-2*hn)*yn*Y-hn*H-en*E

# %%
def check_equivar(c):
    p_inv=-exp(-2*h)*y*Y-h*H-e*E
    c_0=c.subs({y:0,h:0,e:0})
    r=p_inv.Ad(c_0,mod='CE')-c
    simplify_cochain(r)
    if r==C.elt({}): return True
    else: return r

# %%
F1,K1=P.normal_frame(1)
simplify_cochain(K1)
print('K1 =',K1)
# Out:
# weight 1 curvature computed in time 0.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 1.0 sec
# weight 1 normalization complete in time 2.0 sec
# K1 = 0

# %%
F2,K2=P.normal_frame(2)
simplify_cochain(K2)
print('K2 =',K2)
# Out:
# weight 2 curvature computed in time 8.0 sec
# weight 2 projection computed in time 0.0 sec
# weight 2 preimage cochain computed in time 0.0 sec
# weight 2 Matrix exponential complete in time 1.0 sec
# weight 2 normalization complete in time 10.0 sec
# K2 = 0

# %%
F3,K3=P.normal_frame(3)
simplify_cochain(K3)
# Out:
# weight 3 curvature computed in time 21.0 sec
# weight 3 projection computed in time 1.0 sec
# weight 3 preimage cochain computed in time 0.0 sec
# weight 3 Matrix exponential complete in time 1.0 sec
# weight 3 normalization complete in time 22.0 sec

# %%
F4,K4=P.normal_frame(4)
simplify_cochain(K4)
# Out:
# weight 4 curvature computed in time 3.0 min 44.0 sec
# weight 4 projection computed in time 1.0 sec
# weight 4 preimage cochain computed in time 0.0 sec
# weight 4 Matrix exponential complete in time 1.0 sec
# weight 4 normalization complete in time 3.0 min 46.0 sec

# %%
F5,K5=P.normal_frame(5)
simplify_cochain(K5)
# Out:
# weight 5 curvature computed in time 43.0 sec
# weight 5 projection computed in time 2.0 sec
# weight 5 preimage cochain computed in time 0.0 sec
# weight 5 Matrix exponential complete in time 1.0 sec
# weight 5 normalization complete in time 46.0 sec

# %%
F6,K6=P.normal_frame(6)
simplify_cochain(K6)
# Out:
# weight 6 curvature computed in time 51.0 sec
# weight 6 projection computed in time 5.0 sec
# weight 6 preimage cochain computed in time 1.0 sec
# weight 6 Matrix exponential complete in time 7.0 sec
# weight 6 normalization complete in time 1.0 min 4.0 sec

# %%
# %run helpers.ipynb

# %%
# printing coming from ds_subs
K3_subbed=ds_subs(K3,D_JS,D)
simplify_cochain(K3_subbed)
K3_subbed_symb=simplify(K3_subbed.symb_expr())

# %%
K4_subbed=ds_subs(K4,D_JS,D)
simplify_cochain(K4_subbed)
K4_h=simplify(C.subspace_proj(K4_subbed,'harmonic').symb_expr())

# %%
K5_subbed=ds_subs(K5,D_JS,D)
simplify_cochain(K5_subbed)
K5_h=simplify(C.subspace_proj(K5_subbed,'harmonic').symb_expr())

# %%
K6_subbed=ds_subs(K6,D_JS,D)
simplify_cochain(K6_subbed)

# %%
K5_subbed_symb=simplify(K5_subbed.symb_expr())

# %%
K3_h=simplify(C.subspace_proj(K3_subbed,'harmonic').symb_expr())
K4_h=simplify(C.subspace_proj(K4_subbed,'harmonic').symb_expr())
K5_h=simplify(C.subspace_proj(K5_subbed,'harmonic').symb_expr())
K6_h=simplify(C.subspace_proj(K6_subbed,'harmonic').symb_expr())

# %%
K3_h
# Out:
# (-2*K[3, 10, 8] + 2*K[3, 10, 9, 3] - K[4, 10, 10, 3, 3] + 2*K[4, 9, 7] + 2*K[4, 9, 9, 3, 3] + 5*K[5, 8, 9, 3, 3])*(3*{{e_1^*\wedge}e_4^*\otimes}e_2 + 6*{{e_1^*\wedge}e_5^*\otimes}e_3 + 5*{{e_1^*\wedge}e_6^*\otimes}e_4 - 3*{{e_2^*\wedge}e_3^*\otimes}e_2 - 3*{{e_2^*\wedge}e_4^*\otimes}e_3 + {{e_2^*\wedge}e_5^*\otimes}e_4 + 5*{{e_2^*\wedge}e_6^*\otimes}e_5 - 4*{{e_3^*\wedge}e_4^*\otimes}e_4 - 4*{{e_3^*\wedge}e_5^*\otimes}e_5 + 5*{{e_3^*\wedge}e_6^*\otimes}e_6 - 9*{{e_4^*\wedge}e_5^*\otimes}e_6)*exp(e - h)/10

# %%
simplify(K4_h-K3_h)
# Out:
# (5*{{X^*\wedge}e_4^*\otimes}e_1 + 8*{{X^*\wedge}e_5^*\otimes}e_2 + 5*{{X^*\wedge}e_6^*\otimes}e_3)*exp(8*h)*K[3, 9, 6]/18

# %%
simplify(K5_h-K4_h)
# Out:
# 0

# %%
simplify(K6_h-K5_h)
# Out:
# {{X^*\wedge}e_6^*\otimes}e_1*(18*K[3, 9, 4] - 5*K[3, 9, 6, 3, 3])*exp(12*h)/18

# %%
MoreJS={}
for i in range(3,len(g.basis)):
    for j in range(3,len(g.basis)):
        for k in range(3,len(g.basis)):
            MoreJS[K[i,j,k,5]]=K[i,j,k,4,3]-K[i,j,k,3,4]-K[3,4,3]*K[i,j,k,3]-K[3,4,4]*K[i,j,k,4]
