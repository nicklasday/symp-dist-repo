# %%
from sympy import *
from random import randint
# %run Geom_Prolongation.ipynb
# %run Particular_Distributions.ipynb

# %%
#
g=Symp_symb(9)
E=g.ext_alg
C=g.cochain_complex
D,D_JS=Invol_7_Prenorm_distr(g,6)
P=Geom_Prolongation(D,D_JS)
y,h,e=symbols('y,h,e')
K=IndexedBase('K')
Y,H,E,X,e1,e2,e3,e4,e5,e6,e7,e8,N=g.basis
# Out:
# Jacobi id of weight 1 computed in time 17.0 sec
# Jacobi id of weight 2 computed in time 22.0 sec
# Jacobi id of weight 3 computed in time 47.0 sec
# Jacobi id of weight 4 computed in time 1.0 min 25.0 sec
# Jacobi id of weight 5 computed in time 5.0 min 52.0 sec
# Jacobi id of weight 6 computed in time 1.0 hrs 3.0 min 57.0 sec

# %%
D0=Invol_7_Prenorm_distr(g,0)[0]
D1=Particular_distr(g,{},0)[0]

# %%
for i in range(len(D0.basis)):
    for j in range(i+1,len(D0.basis)):
        print('[',g.basis[i+3],g.basis[j+3],'] :',g.elt(D1.basis[i].bracket(D1.basis[j]).vec)-g.elt((D0.basis[i]).bracket(D0.basis[j]).vec))
    print()
# Out:
# [ X e_1 ] : K[3, 4, 4]*e_1
# [ X e_2 ] : K[3, 5, 4]*e_1 + K[3, 5, 5]*e_2
# [ X e_3 ] : K[3, 6, 4]*e_1 + K[3, 6, 5]*e_2 + K[3, 6, 6]*e_3
# [ X e_4 ] : K[3, 7, 4]*e_1 + K[3, 7, 5]*e_2 + K[3, 7, 6]*e_3 + K[3, 7, 7]*e_4
# [ X e_5 ] : K[3, 8, 4]*e_1 + K[3, 8, 5]*e_2 + K[3, 8, 6]*e_3 + K[3, 8, 7]*e_4 + K[3, 8, 8]*e_5
# [ X e_6 ] : K[3, 9, 4]*e_1 + K[3, 9, 5]*e_2 + K[3, 9, 6]*e_3 + K[3, 9, 7]*e_4 + K[3, 9, 8]*e_5 + K[3, 9, 9]*e_6
# [ X e_7 ] : K[3, 10, 4]*e_1 + K[3, 10, 5]*e_2 + K[3, 10, 6]*e_3 + K[3, 10, 7]*e_4 + K[3, 10, 8]*e_5 + K[3, 10, 9]*e_6 + K[3, 10, 10]*e_7
# [ X e_8 ] : 0
# [ X N ] : 0
#
# [ e_1 e_2 ] : K[4, 5, 3]*X
# [ e_1 e_3 ] : K[4, 6, 3]*X
# [ e_1 e_4 ] : 0
# [ e_1 e_5 ] : 0
# [ e_1 e_6 ] : 0
# [ e_1 e_7 ] : 0
# [ e_1 e_8 ] : K[4, 11, 3]*X + K[4, 11, 4]*e_1 + K[4, 11, 5]*e_2 + K[4, 11, 6]*e_3 + K[4, 11, 7]*e_4 + K[4, 11, 8]*e_5 + K[4, 11, 9]*e_6 + K[4, 11, 10]*e_7 + K[4, 11, 11]*e_8
# [ e_1 N ] : 0
#
# [ e_2 e_3 ] : K[5, 6, 3]*X + K[5, 6, 7]*e_4
# [ e_2 e_4 ] : K[5, 7, 8]*e_5
# [ e_2 e_5 ] : K[5, 8, 9]*e_6
# [ e_2 e_6 ] : K[5, 9, 10]*e_7
# [ e_2 e_7 ] : 0
# [ e_2 e_8 ] : 0
# [ e_2 N ] : 0
#
# [ e_3 e_4 ] : K[6, 7, 8]*e_5 + K[6, 7, 9]*e_6
# [ e_3 e_5 ] : K[6, 8, 9]*e_6 + K[6, 8, 10]*e_7
# [ e_3 e_6 ] : 0
# [ e_3 e_7 ] : 0
# [ e_3 e_8 ] : 0
# [ e_3 N ] : 0
#
# [ e_4 e_5 ] : 0
# [ e_4 e_6 ] : 0
# [ e_4 e_7 ] : 0
# [ e_4 e_8 ] : 0
# [ e_4 N ] : 0
#
# [ e_5 e_6 ] : 0
# [ e_5 e_7 ] : 0
# [ e_5 e_8 ] : 0
# [ e_5 N ] : 0
#
# [ e_6 e_7 ] : 0
# [ e_6 e_8 ] : 0
# [ e_6 N ] : 0
#
# [ e_7 e_8 ] : 0
# [ e_7 N ] : 0
#
# [ e_8 N ] : 0

# %%
# # Sort the Jacobi indices by weight
JI_ind_wghts={}
p=g.basis.index(g.m_basis[0])
for i in range(p,len(g.basis)):
    for j in range(i+1,len(g.basis)):
        for k in range(j+1,len(g.basis)):
            for l in range(p,len(g.basis)):
                w=-g.basis[i].wght-g.basis[j].wght-g.basis[k].wght+g.basis[l].wght
                if not w in JI_ind_wghts: JI_ind_wghts[w]=[]
                JI_ind_wghts[w].append((i,j,k,l))

# %%
F1,K1=P.normal_frame(1)
simplify_cochain(K1)
print('K1 =',K1)
# Out:
# weight 1 curvature computed in time 1.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 2.0 sec
# weight 1 differential substitutions complete in time 0.0 sec
# weight 1 normalization complete in time 4.0 sec
# K1 = 0

# %%
F2,K2=P.normal_frame(2)
simplify_cochain(K2)
print('K2 =',K2)
# Out:
# weight 2 curvature computed in time 2.0 min 0.0 sec
# weight 2 projection computed in time 0.0 sec
# weight 2 preimage cochain computed in time 1.0 sec
# weight 2 Matrix exponential complete in time 10.0 sec
# weight 2 differential substitutions complete in time 1.0 sec
# weight 2 normalization complete in time 2.0 min 12.0 sec
# K2 = 7*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/31*(e_1,e_2,e_1)+7*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/31*(e_1,e_3,e_2)+(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_1,e_4,e_3)+15*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/62*(e_1,e_5,e_4)+8*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/31*(e_1,e_6,e_5)+7*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_1,e_7,e_6)+7*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/62*(e_1,e_8,e_7)+29*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_2,e_3,e_3)+29*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_2,e_4,e_4)+(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/62*(e_2,e_5,e_5)+25*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_2,e_6,e_6)+21*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_2,e_7,e_7)+7*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/62*(e_2,e_8,e_8)+27*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_3,e_4,e_5)+27*(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_3,e_5,e_6)+(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/31*(e_3,e_6,e_7)+35*(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*exp(e - 5*h)/124*(e_3,e_7,e_8)+(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/4*(e_4,e_5,e_7)+(-K[3, 11, 11]*K[7, 8, 11] - 2*K[6, 10, 11])*exp(e - 5*h)/4*(e_4,e_6,e_8)

# %%
F3,K3=P.normal_frame(3)
simplify_cochain(K3)
# Out:
# weight 3 curvature computed in time 9.0 min 5.0 sec
# weight 3 projection computed in time 1.0 sec
# weight 3 preimage cochain computed in time 3.0 sec
# weight 3 Matrix exponential complete in time 19.0 sec
# weight 3 differential substitutions complete in time 8.0 sec
# weight 3 normalization complete in time 9.0 min 36.0 sec

# %%
F4,K4=P.normal_frame(4)
simplify_cochain(K4)
# Out:
# weight 4 curvature computed in time 20.0 min 0.0 sec
# weight 4 projection computed in time 4.0 sec
# weight 4 preimage cochain computed in time 15.0 sec
# weight 4 Matrix exponential complete in time 37.0 sec
# weight 4 differential substitutions complete in time 41.0 sec
# weight 4 normalization complete in time 21.0 min 36.0 sec

# %%
F5,K5=P.normal_frame(5)
# Out:
# weight 5 curvature computed in time 59.0 min 4.0 sec
# weight 5 projection computed in time 11.0 sec
# weight 5 preimage cochain computed in time 1.0 min 30.0 sec
# weight 5 Matrix exponential complete in time 1.0 min 7.0 sec
# weight 5 differential substitutions complete in time 5.0 min 4.0 sec
# weight 5 normalization complete in time 1.0 hrs 6.0 min 56.0 sec

# %%
F6,K6=P.normal_frame(6)
# Out:
# weight 6 curvature computed in time 2.0 hrs 21.0 min 46.0 sec
# weight 6 projection computed in time 1.0 min 4.0 sec
# weight 6 preimage cochain computed in time 23.0 min 30.0 sec
# weight 6 Matrix exponential complete in time 2.0 min 27.0 sec
# weight 6 differential substitutions complete in time 1.0 hrs 8.0 min 34.0 sec
# weight 6 normalization complete in time 3.0 hrs 57.0 min 20.0 sec

# %%
F7,K7=P.normal_frame(7)
# Out:
# weight 7 curvature computed in time 5.0 min 53.0 sec
# weight 7 projection computed in time 10.0 sec
# weight 7 preimage cochain computed in time 2.0 sec
# weight 7 Matrix exponential complete in time 10.0 sec
# weight 7 differential substitutions complete in time 1.0 min 10.0 sec
# weight 7 normalization complete in time 7.0 min 24.0 sec

# %%
F8,K8=P.normal_frame(8)
# Out:
# weight 8 curvature computed in time 8.0 min 40.0 sec
# weight 8 projection computed in time 25.0 sec
# weight 8 preimage cochain computed in time 8.0 sec
# weight 8 Matrix exponential complete in time 1.0 min 52.0 sec
# weight 8 differential substitutions complete in time 5.0 min 40.0 sec
# weight 8 normalization complete in time 16.0 min 45.0 sec

# %%
K2_subbed=ds_subs(K2,D_JS,D)
K3_subbed=ds_subs(K3,D_JS,D)
K4_subbed=ds_subs(K4,D_JS,D)
K5_subbed=ds_subs(K5,D_JS,D)
K6_subbed=ds_subs(K6,D_JS,D)
# K7_subbed=ds_subs(K7,D_JS,D)
# K8_subbed=ds_subs(K8,D_JS,D)

# %%
K2h=factor(C.subspace_proj(K2_subbed,'harmonic').symb_expr())
K3h=factor(C.subspace_proj(K3_subbed,'harmonic').symb_expr()-K2h)
K4h=(C.subspace_proj(K4_subbed,'harmonic').symb_expr()-K2h-K3h)
K5h=(C.subspace_proj(K5_subbed,'harmonic').symb_expr()-K2h-K3h-K4h)
K6h=(C.subspace_proj(K6_subbed,'harmonic').symb_expr()-K2h-K3h-K4h-K5h)
# K7h=(C.subspace_proj(K7_subbed,'harmonic').symb_expr()-K2h-K3h-K4h-K5h-K6h)
# K8h=(C.subspace_proj(K7_subbed,'harmonic').symb_expr()-K2h-K3h-K4h-K5h-K6h-K7h)

# %%
kill_Wilc={}
kill_V={}
V_strs=[str(b) for b in g.basis[4:-1]]
for w in C.basis(2):
    for c in C.basis(2,w):
        if str(c.components[0])=='X' and str(c.components[1]) in V_strs and str(c.components[2]) in V_strs:
            kill_Wilc[c.symb_expr()]=0
        if str(c.components[0]) in V_strs and str(c.components[1]) in V_strs and str(c.components[2]) in V_strs:
            kill_V[c.symb_expr()]=0

NW2_tensor=K2h.xreplace(kill_Wilc)
NW3_tensor=K3h.xreplace(kill_Wilc)
W4_tensor=K4h.xreplace(kill_V)
NW4_tensor=K4h.xreplace(kill_Wilc)
W6_tensor=K6h.subs(kill_V)
# W7_tensor=K7h.subs(kill_V)
# NW7_tensor=K7h.subs(kill_Wilc)
# W8_tensor=K8h.subs(kill_V)
# NW8_tensor=K8h.subs(kill_Wilc)

# %%
# # Should make sure these really do factor; i.e., they aren't a sum of harmonic invariants
for invar in [NW2_tensor,NW3_tensor,W4_tensor,NW4_tensor,W6_tensor]:
    print(factor(invar))
# Out:
# -(K[3, 11, 11]*K[7, 8, 11] + 2*K[6, 10, 11])*(28*{{e_1^*\wedge}e_2^*\otimes}e_1 + 28*{{e_1^*\wedge}e_3^*\otimes}e_2 - {{e_1^*\wedge}e_4^*\otimes}e_3 - 30*{{e_1^*\wedge}e_5^*\otimes}e_4 - 32*{{e_1^*\wedge}e_6^*\otimes}e_5 - 7*{{e_1^*\wedge}e_7^*\otimes}e_6 + 14*{{e_1^*\wedge}e_8^*\otimes}e_7 + 29*{{e_2^*\wedge}e_3^*\otimes}e_3 + 29*{{e_2^*\wedge}e_4^*\otimes}e_4 + 2*{{e_2^*\wedge}e_5^*\otimes}e_5 - 25*{{e_2^*\wedge}e_6^*\otimes}e_6 - 21*{{e_2^*\wedge}e_7^*\otimes}e_7 + 14*{{e_2^*\wedge}e_8^*\otimes}e_8 + 27*{{e_3^*\wedge}e_4^*\otimes}e_5 + 27*{{e_3^*\wedge}e_5^*\otimes}e_6 - 4*{{e_3^*\wedge}e_6^*\otimes}e_7 - 35*{{e_3^*\wedge}e_7^*\otimes}e_8 + 31*{{e_4^*\wedge}e_5^*\otimes}e_7 + 31*{{e_4^*\wedge}e_6^*\otimes}e_8)*exp(e)*exp(-5*h)/124
# -(1040*K[3, 11, 10, 4] + 2080*K[3, 11, 10]*K[3, 4, 3] - 756*K[3, 11, 10]*K[7, 8, 11] - 1120*K[3, 11, 11, 3, 4] - 2240*K[3, 11, 11, 3]*K[3, 4, 3] + 1134*K[3, 11, 11, 3]*K[7, 8, 11] + 280*K[3, 11, 11, 4]*K[3, 11, 11] + 280*K[3, 11, 11]**2*K[3, 4, 3] + 96*K[3, 11, 11]**2*K[7, 8, 11] + 759*K[3, 11, 11]*K[6, 10, 11] + 720*K[3, 11, 11]*K[7, 8, 10] - 1344*K[4, 10, 8] - 756*K[8, 9, 11])*(3*{{e_1^*\wedge}e_4^*\otimes}e_2 + 6*{{e_1^*\wedge}e_5^*\otimes}e_3 + 8*{{e_1^*\wedge}e_6^*\otimes}e_4 + 9*{{e_1^*\wedge}e_7^*\otimes}e_5 + 7*{{e_1^*\wedge}e_8^*\otimes}e_6 - 3*{{e_2^*\wedge}e_3^*\otimes}e_2 - 3*{{e_2^*\wedge}e_4^*\otimes}e_3 - 2*{{e_2^*\wedge}e_5^*\otimes}e_4 - {{e_2^*\wedge}e_6^*\otimes}e_5 + 2*{{e_2^*\wedge}e_7^*\otimes}e_6 + 7*{{e_2^*\wedge}e_8^*\otimes}e_7 - {{e_3^*\wedge}e_4^*\otimes}e_4 - {{e_3^*\wedge}e_5^*\otimes}e_5 - 3*{{e_3^*\wedge}e_6^*\otimes}e_6 - 5*{{e_3^*\wedge}e_7^*\otimes}e_7 + 7*{{e_3^*\wedge}e_8^*\otimes}e_8 + 2*{{e_4^*\wedge}e_5^*\otimes}e_6 + 2*{{e_4^*\wedge}e_6^*\otimes}e_7 - 12*{{e_4^*\wedge}e_7^*\otimes}e_8 + 14*{{e_5^*\wedge}e_6^*\otimes}e_8)*exp(e)*exp(-3*h)/22680
# -(7*{{X^*\wedge}e_4^*\otimes}e_1 + 16*{{X^*\wedge}e_5^*\otimes}e_2 + 20*{{X^*\wedge}e_6^*\otimes}e_3 + 16*{{X^*\wedge}e_7^*\otimes}e_4 + 7*{{X^*\wedge}e_8^*\otimes}e_5)*(48384*K[3, 11, 10, 3, 3] - 20160*K[3, 11, 10, 3]*K[3, 11, 11] - 3008*K[3, 11, 10]**2 + 896*K[3, 11, 10]*K[3, 11, 11, 3] - 112*K[3, 11, 10]*K[3, 11, 11]**2 - 75264*K[3, 11, 11, 3, 3, 3] + 65856*K[3, 11, 11, 3, 3]*K[3, 11, 11] + 40768*K[3, 11, 11, 3]**2 - 17248*K[3, 11, 11, 3]*K[3, 11, 11]**2 + 343*K[3, 11, 11]**4 - 10752*K[3, 11, 8])*exp(8*h)/709632
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 3
#       1 # # Should make sure these really do factor; i.e., they aren't a sum of harmonic invariants
#       2 for invar in [NW2_tensor,NW3_tensor,W4_tensor,NW4_tensor,W6_tensor]:
# ----> 3     print(factor(invar))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polytools.py:6542, in factor(f, deep, *gens, **args)
#    6539     return f.xreplace(partials)
#    6541 try:
# -> 6542     return _generic_factor(f, gens, args, method='factor')
#    6543 except PolynomialError as msg:
#    6544     if not f.is_commutative:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polytools.py:6223, in _generic_factor(expr, gens, args, method)
#    6221 opt = options.build_options(gens, args)
#    6222 opt['fraction'] = fraction
# -> 6223 return _symbolic_factor(sympify(expr), opt, method)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polytools.py:6163, in _symbolic_factor(expr, opt, method)
#    6161     if hasattr(expr,'_eval_factor'):
#    6162         return expr._eval_factor()
# -> 6163     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6164     return _keep_coeff(coeff, _factors_product(factors))
#    6165 elif hasattr(expr, 'args'):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polytools.py:6128, in _symbolic_factor_list(expr, opt, method)
#    6125 else:
#    6126     func = getattr(poly, method + '_list')
# -> 6128     _coeff, _factors = func()
#    6129     if _coeff is not S.One:
#    6130         if exp.is_Integer:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polytools.py:3350, in Poly.factor_list(f)
#    3348 if hasattr(f.rep, 'factor_list'):
#    3349     try:
# -> 3350         coeff, factors = f.rep.factor_list()
#    3351     except DomainError:
#    3352         return S.One, [(f, 1)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\polyclasses.py:823, in DMP.factor_list(f)
#     821 def factor_list(f):
#     822     """Returns a list of irreducible factors of ``f``. """
# --> 823     coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     824     return coeff, [ (f.per(g), k) for g, k in factors ]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\factortools.py:1423, in dmp_factor_list(f, u, K0)
#    1421 if K.is_ZZ:
#    1422     levels, f, v = dmp_exclude(f, u, K)
# -> 1423     coeff, factors = dmp_zz_factor(f, v, K)
#    1425     for i, (f, k) in enumerate(factors):
#    1426         factors[i] = (dmp_include(f, levels, v, K), k)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\factortools.py:1154, in dmp_zz_factor(f, u, K)
#    1151 if all(d <= 0 for d in dmp_degree_list(g, u)):
#    1152     return cont, []
# -> 1154 G, g = dmp_primitive(g, u, K)
#    1156 factors = []
#    1158 if dmp_degree(g, u) > 0:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1818, in dmp_primitive(f, u, K)
#    1804 def dmp_primitive(f, u, K):
#    1805     """
#    1806     Returns multivariate content and a primitive polynomial.
#    1807
#    (...)
#    1816
#    1817     """
# -> 1818     cont, v = dmp_content(f, u, K), u - 1
#    1820     if dmp_zero_p(f, u) or dmp_one_p(cont, v, K):
#    1821         return cont, f
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
#     [... skipping similar frames: _dmp_inner_gcd at line 1553 (9 times), dmp_content at line 1793 (9 times), dmp_gcd at line 1625 (9 times), dmp_inner_gcd at line 1584 (9 times), _dmp_rr_trivial_gcd at line 912 (8 times), _dmp_simplify_gcd at line 952 (8 times), dmp_zz_heu_gcd at line 1311 (8 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1334, in dmp_zz_heu_gcd(f, g, u, K)
#    1331 v = u - 1
#    1333 if not (dmp_zero_p(ff, v) or dmp_zero_p(gg, v)):
# -> 1334     h, cff, cfg = dmp_zz_heu_gcd(ff, gg, v, K)
#    1336     h = _dmp_zz_gcd_interpolate(h, x, v, K)
#    1337     h = dmp_ground_primitive(h, u, K)[1]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
#     [... skipping similar frames: _dmp_rr_trivial_gcd at line 912 (6 times), dmp_zz_heu_gcd at line 1311 (6 times), _dmp_inner_gcd at line 1553 (5 times), _dmp_simplify_gcd at line 952 (5 times), dmp_content at line 1793 (5 times), dmp_gcd at line 1625 (5 times), dmp_inner_gcd at line 1584 (5 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:952, in _dmp_simplify_gcd(f, g, u, K)
#     950 if not df:
#     951     F = dmp_LC(f, K)
# --> 952     G = dmp_content(g, u, K)
#     953 else:
#     954     F = dmp_content(f, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1793, in dmp_content(f, u, K)
#    1790     return cont
#    1792 for c in f[1:]:
# -> 1793     cont = dmp_gcd(cont, c, v, K)
#    1795     if dmp_one_p(cont, v, K):
#    1796         break
#
#     [... skipping similar frames: _dmp_inner_gcd at line 1553 (1 times), _dmp_rr_trivial_gcd at line 912 (1 times), dmp_gcd at line 1625 (1 times), dmp_inner_gcd at line 1584 (1 times), dmp_zz_heu_gcd at line 1311 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:958, in _dmp_simplify_gcd(f, g, u, K)
#     955         G = dmp_LC(g, K)
#     957 v = u - 1
# --> 958 h = dmp_gcd(F, G, v, K)
#     960 cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     961 cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#
#     [... skipping similar frames: _dmp_inner_gcd at line 1553 (1 times), _dmp_rr_trivial_gcd at line 912 (1 times), dmp_gcd at line 1625 (1 times), dmp_inner_gcd at line 1584 (1 times), dmp_zz_heu_gcd at line 1311 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:958, in _dmp_simplify_gcd(f, g, u, K)
#     955         G = dmp_LC(g, K)
#     957 v = u - 1
# --> 958 h = dmp_gcd(F, G, v, K)
#     960 cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     961 cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#
#     [... skipping similar frames: _dmp_inner_gcd at line 1553 (3 times), _dmp_rr_trivial_gcd at line 912 (3 times), dmp_gcd at line 1625 (3 times), dmp_inner_gcd at line 1584 (3 times), dmp_zz_heu_gcd at line 1311 (3 times), _dmp_simplify_gcd at line 958 (2 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:958, in _dmp_simplify_gcd(f, g, u, K)
#     955         G = dmp_LC(g, K)
#     957 v = u - 1
# --> 958 h = dmp_gcd(F, G, v, K)
#     960 cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     961 cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1625, in dmp_gcd(f, g, u, K)
#    1608 def dmp_gcd(f, g, u, K):
#    1609     """
#    1610     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1611
#    (...)
#    1623
#    1624     """
# -> 1625     return dmp_inner_gcd(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1584, in dmp_inner_gcd(f, g, u, K)
#    1581     return dup_inner_gcd(f, g, K)
#    1583 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1584 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1586 return (dmp_inflate(h, J, u, K),
#    1587         dmp_inflate(cff, J, u, K),
#    1588         dmp_inflate(cfg, J, u, K))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1553, in _dmp_inner_gcd(f, g, u, K)
#    1551 if K.is_ZZ and query('USE_HEU_GCD'):
#    1552     try:
# -> 1553         return dmp_zz_heu_gcd(f, g, u, K)
#    1554     except HeuristicGCDFailed:
#    1555         pass
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:1311, in dmp_zz_heu_gcd(f, g, u, K)
#    1308 if not u:
#    1309     return dup_zz_heu_gcd(f, g, K)
# -> 1311 result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1313 if result is not None:
#    1314     return result
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:912, in _dmp_rr_trivial_gcd(f, g, u, K)
#     910     return dmp_one(u, K), f, g
#     911 elif query('USE_SIMPLIFY_GCD'):
# --> 912     return _dmp_simplify_gcd(f, g, u, K)
#     913 else:
#     914     return None
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\euclidtools.py:960, in _dmp_simplify_gcd(f, g, u, K)
#     957 v = u - 1
#     958 h = dmp_gcd(F, G, v, K)
# --> 960 cff = [ dmp_quo(cf, h, v, K) for cf in f ]
#     961 cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     963 return [h], cff, cfg
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1671, in dmp_quo(f, g, u, K)
#    1653 def dmp_quo(f, g, u, K):
#    1654     """
#    1655     Returns exact polynomial quotient in ``K[X]``.
#    1656
#    (...)
#    1669
#    1670     """
# -> 1671     return dmp_div(f, g, u, K)[0]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1629, in dmp_div(f, g, u, K)
#    1627     return dmp_ff_div(f, g, u, K)
#    1628 else:
# -> 1629     return dmp_rr_div(f, g, u, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
#     [... skipping similar frames: dmp_rr_div at line 1389 (2 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1389, in dmp_rr_div(f, g, u, K)
#    1387 while True:
#    1388     lc_r = dmp_LC(r, K)
# -> 1389     c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1391     if not dmp_zero_p(R, v):
#    1392         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:1397, in dmp_rr_div(f, g, u, K)
#    1394 j = dr - dg
#    1396 q = dmp_add_term(q, c, j, u, K)
# -> 1397 h = dmp_mul_term(g, c, j, u, K)
#    1398 r = dmp_sub(r, h, u, K)
#    1400 _dr, dr = dr, dmp_degree(r, u)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (2 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\polys\densearith.py:567, in dmp_add(f, g, u, K)
#     563     return dup_add(f, g, K)
#     565 df = dmp_degree(f, u)
# --> 567 if df < 0:
#     568     return g
#     570 dg = dmp_degree(g, u)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\expr.py:376, in Expr.__lt__(self, other)
#     373 @sympify_return([('other', 'Expr')], NotImplemented)
#     374 def __lt__(self, other):
#     375     from .relational import StrictLessThan
# --> 376     return StrictLessThan(self, other)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:833, in _Inequality.__new__(cls, lhs, rhs, **options)
#     824             raise TypeError("Invalid NaN comparison")
#     825     # First we invoke the appropriate inequality method of `lhs`
#     826     # (e.g., `lhs.__lt__`).  That method will try to reduce to
#     827     # boolean or raise an exception.  It may keep calling
#    (...)
#     831     # exception).  In that case, it must call us with
#     832     # `evaluate=False` to prevent infinite recursion.
# --> 833     return cls._eval_relation(lhs, rhs, **options)
#     835 # make a "non-evaluated" Expr for the inequality
#     836 return Relational.__new__(cls, lhs, rhs, **options)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:840, in _Inequality._eval_relation(cls, lhs, rhs, **options)
#     838 @classmethod
#     839 def _eval_relation(cls, lhs, rhs, **options):
# --> 840     val = cls._eval_fuzzy_relation(lhs, rhs)
#     841     if val is None:
#     842         return cls(lhs, rhs, evaluate=False)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:1167, in StrictLessThan._eval_fuzzy_relation(cls, lhs, rhs)
#    1165 @classmethod
#    1166 def _eval_fuzzy_relation(cls, lhs, rhs):
# -> 1167     return is_lt(lhs, rhs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:1246, in is_lt(lhs, rhs, assumptions)
#    1241 def is_lt(lhs, rhs, assumptions=None):
#    1242     """Fuzzy bool for lhs is strictly less than rhs.
#    1243
#    1244     See the docstring for :func:`~.is_ge` for more.
#    1245     """
# -> 1246     return fuzzy_not(is_ge(lhs, rhs, assumptions))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:1368, in is_ge(lhs, rhs, assumptions)
#    1366     return retval
#    1367 else:
# -> 1368     n2 = _n2(lhs, rhs)
#    1369     if n2 is not None:
#    1370         # use float comparison for infinity.
#    1371         # otherwise get stuck in infinite recursion
#    1372         if n2 in (S.Infinity, S.NegativeInfinity):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\relational.py:1203, in _n2(a, b)
#    1200 # /!\ it is very important (see issue 8245) not to
#    1201 # use a re-evaluated number in the calculation of dif
#    1202 if a.is_comparable and b.is_comparable:
# -> 1203     dif = (a - b).evalf(2)
#    1204     if dif.is_comparable:
#    1205         return dif
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\decorators.py:65, in __sympifyit.<locals>.__sympifyit_wrapper(a, b)
#      63     if not hasattr(b, '_op_priority'):
#      64         b = sympify(b, strict=True)
# ---> 65     return func(a, b)
#      66 except SympifyError:
#      67     return retval
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\numbers.py:3503, in NegativeInfinity.__sub__(self, other)
#    3500 @_sympifyit('other', NotImplemented)
#    3501 def __sub__(self, other):
#    3502     if isinstance(other, Number) and global_parameters.evaluate:
# -> 3503         if other in (S.NegativeInfinity, S.NaN):
#    3504             return S.NaN
#    3505         return self
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\numbers.py:3721, in NaN.__eq__(self, other)
#    3718 def __hash__(self):
#    3719     return super().__hash__()
# -> 3721 def __eq__(self, other):
#    3722     # NaN is structurally equal to another NaN
#    3723     return other is S.NaN
#    3725 def __ne__(self, other):
#
# KeyboardInterrupt:

# %%
# # # Should make sure these really do factor; i.e., they aren't a sum of harmonic invariants
# for invar in [NW2_tensor,NW3_tensor,W4_tensor,NW4_tensor,W6_tensor,W7_tensor,NW7_tensor,NW8_tensor,W8_tensor]:
#     display(factor(invar))

# %%
NW2=simplify(NW2_tensor.subs({symbols('{{e_1^*\wedge}e_2^*\otimes}e_1'):Rational(31,28)}).subs(kill_V))
NW3=simplify(NW3_tensor.subs({symbols('{{e_1^*\wedge}e_4^*\otimes}e_2'):Rational(-2205,3)}).subs(kill_V))
W4=simplify(W4_tensor.subs({symbols('{{X^*\wedge}e_4^*\otimes}e_1'):66}).subs(kill_Wilc))
NW4=simplify(NW4_tensor.subs({symbols('{{e_1^*\wedge}e_4^*\otimes}e_1'):Rational(-29584,14)}).subs(kill_V))
W6=simplify(W6_tensor.subs({symbols('{{X^*\wedge}e_6^*\otimes}e_1'):Rational(78,7)}).subs(kill_Wilc))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_12764\444851377.py:1: SyntaxWarning: invalid escape sequence '\w'
#   NW2=simplify(NW2_tensor.subs({symbols('{{e_1^*\wedge}e_2^*\otimes}e_1'):Rational(31,28)}).subs(kill_V))
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_12764\444851377.py:2: SyntaxWarning: invalid escape sequence '\w'
#   NW3=simplify(NW3_tensor.subs({symbols('{{e_1^*\wedge}e_4^*\otimes}e_2'):Rational(-2205,3)}).subs(kill_V))
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_12764\444851377.py:3: SyntaxWarning: invalid escape sequence '\w'
#   W4=simplify(W4_tensor.subs({symbols('{{X^*\wedge}e_4^*\otimes}e_1'):66}).subs(kill_Wilc))
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_12764\444851377.py:4: SyntaxWarning: invalid escape sequence '\w'
#   NW4=simplify(NW4_tensor.subs({symbols('{{e_1^*\wedge}e_4^*\otimes}e_1'):Rational(-29584,14)}).subs(kill_V))
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_12764\444851377.py:5: SyntaxWarning: invalid escape sequence '\w'
#   W6=simplify(W6_tensor.subs({symbols('{{X^*\wedge}e_6^*\otimes}e_1'):Rational(78,7)}).subs(kill_Wilc))

# %%
for I in [NW2,NW3,W4,NW4,W6]:
    display(I)

# %%
for I in [NW2,NW3,W4,NW4,W6]:
    print(I)
# Out:
# -exp(e - 5*h)*K[6, 10, 11]/2
# 49*(-16*K[4, 10, 8] - 9*K[8, 9, 11])*exp(e - 3*h)/6
# 0
# 7396*(-1029*K[4, 9, 6] + 1350*K[5, 6, 4] - 175*K[6, 10, 9] + 770*K[6, 7, 6] - 385*K[7, 11, 11] + 385*K[7, 12, 12] + 385*K[7, 8, 8] + 385*K[8, 10, 11])*exp(e - h)/17325
# 0

# %% [markdown]
# ## Syzygies

# %%
from itertools import combinations_with_replacement
from itertools import product
I=IndexedBase('I')
W=IndexedBase('W')
Abstract_Invars={} # keys are weights; values are abstract invariants
Concrete_Invars={I[3]:K3h_coeff,W[4]:K4h_coeff,W[6]:K6h_coeff} # keys are homogeneous invar monomials; vals are the corresponding concrete invars
Harm_Invars={} # keys are weights; values are (abstract_invar,concrete_invar)
Invar_Mats={} # keys are weights; values are mats with cols giving the coords of concrete invars in the concrete monomial basis
Invar_nullspaces={} # keys are weights; values are the nullspaces of the above matrices
Concrete_monom_basis={} # keys are weights; values are lists of monomials which span the concrete invariants in the weight

fundamental_invars=[I[3],W[4],W[6]]

# %%
def coordinatize_in_monom_basis(expr1,basis):
    """Returns the coordinates of expr in the given basis as a list
    INPUTS:
    * 'expr' - a linear combination of the monomials from basis
    * 'basis' - a list of monomials in symbols and Indexed objects"""
    r=[0]*len(basis)
    expr=expand(expr1)
    for A in expr.as_coeff_add()[1]:
        try: r[basis.index(prod(A.as_coeff_mul()[1]))]=A.as_coeff_mul()[0]
        except ValueError: 
            print('coordinatize_in_monom_basis received expr not in span(basis)')
            print('expr =',expr)
            print('basis =',basis)
            return None
    return r

def monomials_in_expr(expr1):
    """Returns the set of all monomials involved in expr, which should be a polynomial over R
    INPUTS:
    * 'expr' - a polynomial in symbols and Indexed objects over R"""
    r=set()
    expr=expand(expr1)
    if isinstance(expr,numbers.Number): return r
    if type(expr)==Add:
        for A in expr.args:
            r=r.union(monomials_in_expr(A))
    if type(expr) in [Mul, Pow]:
        r.add(expr.as_coeff_Mul()[1])
    if type(expr) in [Indexed,Symbol]:
        r.add(expr)
    return r

def higher_der(expr,*ders):
    r=expr
    for i in ders:
        r=D.abn_ind_der(r,i)
    return r

def coeff_add_to_monom_dict(ca):
    r={}
    for A in ca:
        r[A.as_coeff_Mul()[1]]=A.as_coeff_Mul()[0]
    return r

def common_monom(d1,d2):
    return set(d1.keys()).intersection(set(d2.keys()))

# %%
def all_partitions(s,Z):
    """Returns the set of all tuples (d1,d2,...dj) so that z1*d1 + ... + zj*dj=s
    where Z={z1,z2,...zj}
    INPUTS:
    * 's' - a natural number
    * 'Z' - a finite list of distinct natural numbers (without 0)"""

    if s==0: return {tuple([0]*len(Z))}
    if s<0: return set()
    if len(Z)==0:
        return set()
    
    r=set()
    for a in range(s//Z[0]+1):
        new_Z=copy.copy(Z)
        new_Z.remove(Z[0])
        r=r.union({tuple([a]+list(A)) for A in all_partitions(s-a*Z[0],new_Z)})
    return r

def multiply_cart_prod_elts(L):
    r1,r2=1,1
    for a in L:
        a1=[b[0] for b in a]
        a2=[b[1] for b in a]
        r1=r1*prod(a1)
        r2=r2*prod(a2)
    return (r1,r2)

# %%
def Compute_abstract_invars(wght,additional_invars,reshelve=False,unshelve=False):
    """Adds invariants to Abstract_Invars of the given weight by taking derivatives and
    products of previous abstract invariants and by adding the given set of additional invariants.
    Assumes invariants of lower weights have already been computed.
    INPUTS:
    * 'wght' - a natural number weight
    * 'additional_invar' - a set of invariants as pairs (Indexed,expr) (for example {(W[4],5*K[3,9,6]/18)})
    """
    if unshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                Abstract_Invars[wght]=shelf['Standard_norm_Abstract_Invars'+'{j}'.format(j=wght)]
                return None
        except: pass

    # additional invariants
    Abs_candidates={A for A in additional_invars}

    # derivatives of previous invariants
    if wght-1 in Abstract_Invars:
        HI=list(Abstract_Invars[wght-1])
        for invar in HI:
            Abs_candidates=Abs_candidates.union(monomials_in_expr(D.abn_ind_der(invar,3)))
            Abs_candidates=Abs_candidates.union(monomials_in_expr(D.abn_ind_der(invar,4)))
    
    # products of previous invariants
    # The below block is wrong!
    for p in all_partitions(wght,list(range(3,wght))):
        big_list=[list(combinations_with_replacement(Abstract_Invars[list(range(3,wght))[i]],p[i])) for i in range(len(p))]
        p_prods=list(itertools.product(*big_list))
        for pp in p_prods:
            Abs_candidates.add(prod([prod(a) for a in pp]))
    
    Abs_candidates=list(Abs_candidates)

    temp_basis=set()
    for invar in Abs_candidates:
        temp_basis=temp_basis.union(monomials_in_expr(invar))
    temp_basis=list(temp_basis)

    A=zeros(len(temp_basis),0)
    for invar in Abs_candidates:
        A=A.col_insert(shape(A)[1],Matrix(coordinatize_in_monom_basis(invar,temp_basis)))
    pivs=A.rref()[1]
    Abstract_Invars[wght]=[Abs_candidates[i] for i in pivs]

    if reshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                shelf['Standard_norm_Abstract_Invars'+'{j}'.format(j=wght)]=Abstract_Invars[wght]
        except: print('Reshelving of harm_invars in wght',wght,'Failed')

# %%
def Compute_concrete_invars(wght,conc_dict,reshelve=False,unshelve=False):
    """Converts the abstract invariants of weight wght to concrete invariants,
    storing the results in conc_dict, assuming Abstract_Invars[wght] has been computed
    
    WARNING: Unshelving here isn't subdivided by weight, so whatever weight was shelved will be restored,
    overwriting those weights already computed."""
    if unshelve:
        with shelve.open('harm_invars') as shelf:
                conc_dict=shelf['Standard_norm_Concrete_Invars']
                return None
                # for invar in shelf['Standard_norm_conc_dict']:
                #     conc_dict[invar]=shelf['Standard_norm_Concrete_Invars'][Invar]

    for invar in Abstract_Invars[wght]:
        if invar not in fundamental_invars:
            if len(invar.as_coeff_mul()[1])>1:
                temp_subs={a:conc_dict[a] for a in invar.as_coeff_mul()[1]}
                r=invar.xreplace(temp_subs)
            elif type(invar.as_coeff_mul()[1][0])==Pow:
                temp_subs={invar.as_coeff_mul()[1][0].as_base_exp()[0]:conc_dict[invar.as_coeff_mul()[1][0].as_base_exp()[0]]}
                r=invar.xreplace(temp_subs)
            else:
                r=ds_subs(D.abn_ind_der(conc_dict[invar.base[invar.indices[0:-1]]],invar.indices[-1]),D_JS,D)
            conc_dict[invar]=r
    if reshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                shelf['Standard_norm_Concrete_Invars']=conc_dict
        except: pass

# %%
Abstract_Invars={}
Compute_abstract_invars(3,{I[3]},unshelve=True)
Compute_abstract_invars(4,{W[4]},unshelve=True)
Compute_abstract_invars(5,set(),unshelve=True)
Compute_abstract_invars(6,{W[6]},unshelve=True)
Compute_abstract_invars(7,set(),unshelve=True)
Compute_abstract_invars(8,set(),unshelve=True)
Compute_abstract_invars(9,set(),unshelve=True)

# %%
# 45 min to weight 9
time0=time.time()
Compute_concrete_invars(3,Concrete_Invars)
Compute_concrete_invars(4,Concrete_Invars)
Compute_concrete_invars(5,Concrete_Invars)
Compute_concrete_invars(6,Concrete_Invars)
Compute_concrete_invars(7,Concrete_Invars)
time1=time.time()
print('Weights 1-7 computed in time',hrs_min_sec(time1-time0))
Compute_concrete_invars(8,Concrete_Invars)
time2=time.time()
print('Weight 8 computed in time',hrs_min_sec(time2-time1)) # 2 min 30 sec up to here

# %% [markdown]
# ### Manual Attempts

# %%
def Compute_concrete_invars_manual(wght,conc_dict,monom_set):
    """Converts the abstract invariants of weight wght to concrete invariants,
    storing the results in conc_dict if any monomials from monom_set are involved in the result
    
    WARNING: Unshelving here isn't subdivided by weight, so whatever weight was shelved will be restored,
    overwriting those weights already computed."""
    print('Total invars to process:',len(Abstract_Invars[wght]))
    cnt=1
    for invar in Abstract_Invars[wght]:
        if invar not in fundamental_invars:
            time0=time.time()
            if len(invar.as_coeff_mul()[1])>1:
                print('type 1')
                temp_subs={a:conc_dict[a] for a in invar.as_coeff_mul()[1]}
                r=invar.xreplace(temp_subs)
            elif type(invar.as_coeff_mul()[1][0])==Pow:
                print('type 2')
                temp_subs={invar.as_coeff_mul()[1][0].as_base_exp()[0]:conc_dict[invar.as_coeff_mul()[1][0].as_base_exp()[0]]}
                r=invar.xreplace(temp_subs)
            else:
                print('type 3')
                temp1=collect_some(conc_dict[invar.base[invar.indices[0:-1]]])
                print('temp1 =',temp1)
                temp2=D.abn_ind_der(temp1,invar.indices[-1])
                print('temp2 =',temp2)
                r=ds_subs(temp2,D_JS,D)
            if monomials_in_expr(expand(r)).intersection(monom_set)!=set(): conc_dict[invar]=r

            # temporary for testing:
            print(invar,'===>',r)
            print(monomials_in_expr(expand(r)))
        print('invar',cnt,'processed in time',hrs_min_sec(time.time()-time0))

# %%
## collect_some might speed up the process of taking abnormal derivatives

import heapq

def incr_key(d,k):
    """d-dict, k-key; increments value at k or makes d[k]=1"""
    if k in d:
        d[k]=d[k]+1
    else: d[k]=1

def count_terms(expr):
    """A heuristic count of what terms show up a lot in the polynomial expr"""
    r={}
    count_terms_rec(expr,r)
    return r

def count_terms_rec(expr,count_dict):
    if isinstance(expr,numbers.Number): return None
    if type(expr) in [Add,Mul]:
        for a in expr.args: count_terms_rec(a,count_dict)
    if type(expr)==Pow: count_terms_rec(expr.base,count_dict)
    if type(expr) in [Indexed,Symbol]: incr_key(count_dict,expr)

def top_k_keys(d, k):
    if k <= 0:
        return []

    # Create a min-heap to store the top k keys, including their original order
    min_heap = []

    for index, (key, value) in enumerate(d.items()):
        # Push a tuple of (value, original index, key) onto the heap
        heapq.heappush(min_heap, (value, index, key))
        # If the heap size exceeds k, pop the smallest element
        if len(min_heap) > k:
            heapq.heappop(min_heap)

    # Extract the keys from the heap, sorting them by values and original index
    top_keys = [key for _, _, key in sorted(min_heap, key=lambda x: (-x[0], x[1]))]
    
    return top_keys

def collect_some(expr):
    """Chooses some frequently occurring terms in the polynomial expr and collects those terms"""
    ## Count occurrences
    terms=count_terms(expr)
    if terms=={}: return copy.copy(expr)
    total_terms = sum(terms.values()) # use this to decide how many terms to collect
    num_terms=log(total_terms,10) # This is an arbitrary choice
    collect_terms=top_k_keys(terms,num_terms)

    r=copy.copy(expr)
    collect(r,collect_terms,order=None)
    return r

# %%
I3_monoms=monomials_in_expr(Concrete_Invars[I[3]])

# %%
temp=Concrete_Invars[I[3, 4, 3, 3, 4, 4]]

# %%
temp_terms=count_terms(temp)
log(sum(temp_terms.values()),10).evalf()

# %%
collect(temp,K[5,8,9])

# %%
collect(temp,top_k_keys(temp_terms,4))

# %%
temp

# %%
temp1=collect_some(temp)

# %%
D.abn_ind_der(temp,4)

# %%
temp1=collect(temp,[K[3, 9, 6, 4, 4, 4],K[3, 9, 6, 4, 4],K[3, 9, 6, 4],K[3, 9, 6]])

# %%
temp2=D.abn_ind_der(temp1,4)

# %%
# This suggests the derivatives are actually what's taking a long time...surprising
Compute_concrete_invars_manual(9,Concrete_Invars,I3_monoms)

# %%
abstract_t=[]
t=[]
t.append(expand(ds_subs(K3h_coeff**3,D_JS,D)))
abstract_t.append(('Type 0'))

type_count=0

# # Very slow!
# P=list(product([3,4],[3,4],[3,4],[3,4],[3,4],[3,4]))
# print(len(P))
# for i in range(len(P)):
#     print(i)
#     t.append(expand(ds_subs(higher_der(K3h_coeff,*(P[i])),D_JS,D)))
#     abstract_t.append(('Type 2',P[i]))

# # # --------------------------------------------

# Derivatives of W4
P=list(product([3,4],[3,4],[3,4],[3,4],[3,4]))
for i in range(len(P)):
    t.append(expand(ds_subs(higher_der(K4h_coeff,*(P[i])),D_JS,D)))
    abstract_t.append(('Type'+str(type_count),P[i]))
type_count+=1

# # # --------------------------------------------
# (Derivatives of W4)*W3
P=list(product([3,4],[3,4]))
for i in range(len(P)):
    t.append(expand(ds_subs(higher_der(K4h_coeff,*P[i]),D_JS,D)*K3h_coeff))
    abstract_t.append(('Type'+str(type_count),P[i]))
type_count+=1

# (derivatives of W4)*(derivatives of W3)
P=list(product([3,4],[3,4]))
for i in range(len(P)):
    t.append(expand(ds_subs(higher_der(K3h_coeff,P[i][0]),D_JS,D)*ds_subs(higher_der(K4h_coeff,P[i][1]),D_JS,D)))
    abstract_t.append(('Type'+str(type_count),P[i]))
type_count+=1

# W4*(derivatives of W3)
P=list(product([3,4],[3,4]))
for i in range(len(P)):
    t.append(expand(ds_subs(higher_der(K3h_coeff,*P[i]),D_JS,D)*K4h_coeff))
    abstract_t.append(('Type'+str(type_count),P[i]))
type_count+=1

# # # --------------------------------------------

# W6*W3
t.append(expand(K6h_coeff*K3h_coeff))
abstract_t.append(('Type'+str(type_count)))
type_count+=1


# Derivatives of W6
P=list(product([3,4],[3,4],[3,4]))
for i in range(len(P)):
    t.append(expand(ds_subs(higher_der(K6h_coeff,*(P[i])),D_JS,D)))
    abstract_t.append(('Type'+str(type_count),P[i]))
type_count+=1



d=[coeff_add_to_monom_dict(A.as_coeff_add()[1]) for A in t]

# %%
da=coeff_add_to_monom_dict(expand(Concrete_Invars[I[3]**3]).as_coeff_add()[1])
common_mon_dict={}
ctr=1
for k in Abstract_Invars[9]:
    db=coeff_add_to_monom_dict(expand(Concrete_Invars[k]).as_coeff_add()[1])
    common_mon_dict[k]=common_monom(da,db)
    print('Invar',ctr,'=',k,'complete in time',hrs_min_sec(time.time()))

# %%
print(common_mon_dict)

# %%
da=d[0]
for db in d[1:len(d)]:
    if common_monom(da,db)!=set():
        counter={}
        for A in set(da.keys()).intersection(set(db.keys())):
            temp=da[A]/db[A]
            if temp in counter: counter[temp]=counter[temp]+1
            else: counter[temp]=1

        for key in counter:
            if counter[key]>1: print(key,'-->',counter[key])

# %% [markdown]
# ### Systematic Attempts

# %% [markdown]
# #### Compute All (Abstact) Invariant Monomials

# %% [markdown]
# #### Convert Abstract Invariant Monomials into Concrete Invariants

# %%
# Unshelving Concrete_Invars
Compute_concrete_invars(0,Concrete_Invars,unshelve=True)

# %%
# 45 min
time0=time.time()
Compute_concrete_invars(3,Concrete_Invars)
Compute_concrete_invars(4,Concrete_Invars)
Compute_concrete_invars(5,Concrete_Invars)
Compute_concrete_invars(6,Concrete_Invars)
Compute_concrete_invars(7,Concrete_Invars)
time1=time.time()
print('Weights 1-7 computed in time',hrs_min_sec(time1-time0))
Compute_concrete_invars(8,Concrete_Invars)
time2=time.time()
print('Weight 8 computed in time',hrs_min_sec(time2-time1)) # 2 min 30 sec up to here
Compute_concrete_invars(9,Concrete_Invars,reshelve=False)
print('Weight 9 computed in time',hrs_min_sec(time.time()-time2))

# %% [markdown]
# #### Compute Concrete Monomial bases

# %%
def Compute_concrete_monom_basis(wght,reshelve=False,unshelve=False):
    """Computes a basis of monomials spanning the concrete invariants in wght, storing
    the results in Concrete_monom_basis"""
    if unshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                Concrete_monom_basis[wght]=shelf['Standard_norm_Concrete_monom_basis'+'{j}'.format(j=wght)]
                return None
        except: pass

    result=set()
    for A in Abstract_Invars[wght]:
        result=result.union(monomials_in_expr(Concrete_Invars[A]))
    Concrete_monom_basis[wght]=list(result)

    if reshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                shelf['Standard_norm_Concrete_monom_basis'+'{j}'.format(j=wght)]=Concrete_monom_basis[wght]
        except: print('Reshelving of Concrete_monom_basis in wght',wght,'Failed')

# %%
# 3 min 30 sec thru weight 8
for i in range(3,10):
    Compute_concrete_monom_basis(i,unshelve=True)

# %% [markdown]
# #### Coordinatize, Find Syzygies

# %%
def compute_invar_mat(wght,reshelve=False,unshelve=False):
    """Sets the matrix representation of all invariants of given weight as the value Invar_Mats[wght].
    Invar_Mats[wght] is a Matrix with columns given by the Concrete Invariants of weight wght as column i,
    represented in Concrete_monom_basis[wght]
    
    Assumes Concrete_monom_basis[wght] has been computed"""

    if unshelve:
        try:
            with shelve.open('Syzygies') as shelf:
                Invar_Mats[wght]=shelf['Standard_norm_invar_mats'+'{j}'.format(j=wght)]
                return None
        except: pass

    Invar_Mats[wght]=zeros(len(Concrete_monom_basis[wght]),0)
    for A in Abstract_Invars[wght]:
        temp_col=Matrix([[a] for a in coordinatize_in_monom_basis(Concrete_Invars[A],Concrete_monom_basis[wght])])
        Invar_Mats[wght]=Invar_Mats[wght].col_insert(shape(Invar_Mats[wght])[1],temp_col)

    if reshelve:
        try:
            with shelve.open('Syzygies') as shelf:
                shelf['Standard_norm_invar_mats'+'{j}'.format(j=wght)]=Invar_Mats[wght]
        except: print('Reshelving of invar_mats in wght',wght,'Failed')

def compute_Invar_nullspace(wght,reshelve=False,unshelve=False):
    """Assuming compute_invar_mat(wght) has been run, this computes the nullspace of that matrix
     (i.e., the relations between the invariants in the given wght, as columns)"""
    
    if unshelve:
        try:
            with shelve.open('Syzygies') as shelf:
                Invar_nullspaces[wght]=shelf['Standard_norm_invar_nullspaces'+'{j}'.format(j=wght)]
                return None
        except: pass

    Invar_nullspaces[wght]=Invar_Mats[wght].nullspace()

    if reshelve:
        try:
            with shelve.open('Syzygies') as shelf:
                shelf['Standard_norm_invar_nullspaces'+'{j}'.format(j=wght)]=Invar_nullspaces[wght]
        except: print('Reshelving of invar_nullspaces in wght',wght,'Failed')

# %%
# def K_wght(expr):
#     """Given a monomial in the IndexedBase K, returns the weight of """
#     if type(expr)==Add:
#         if expr.as_coeff_add()[0]!=0: r=0
#         else: r=K_wght(expr.as_coeff_add()[1][0])
#         for A in expr.as_coeff_add()[1]:
#             if K_wght(A)!=r:
#                 return None
#         return r
#     if type(expr)==Mul:
#         return sum([K_wght(A) for A in expr.as_coeff_mul()[1]])
#     if type(expr)==Pow:
#         return expr.as_base_exp()[1]*K_wght(expr.as_base_exp()[0])
#     if type(expr)==Rational:
#         return 0
#     if type(expr)==Indexed:
#         r=-g.basis[expr.indices[0]].wght-g.basis[expr.indices[1]].wght+g.basis[expr.indices[2]].wght
#         for i in expr.indices[3:len(expr.indices)]:
#             r=r-g.basis[i].wght
#         return r

# %%
# def Abstract_to_Concrete_Invar(expr):
#     temp_subs={}
#     I_set=Indexed_obj_in_expr(expr)
#     for A in I_set:
#         for wght in Abstract_Invars_vecs:
#             if A in Abstract_Invars_vecs[wght]:
#                 i=list(Abstract_Invars_vecs[wght]).index(A)
#                 w=wght
#         temp_subs[A]=Concrete_Invars_vecs[w][i]
#     return expr.xreplace(temp_subs)

# %%
for wght in Abstract_Invars:
    print(wght,'-->',len(Abstract_Invars[wght]))

print('\n')
for wght in Concrete_monom_basis:
    print(wght,'-->',len(Concrete_monom_basis[wght]))

# %%
# 3 min thru weight 8
for wght in range(3,10):
    time0=time.time()
    compute_invar_mat(wght,unshelve=True)
    print('Invar_mat of weight',wght,'computed in time',hrs_min_sec(time.time()-time0))

# %%
# 1 min thru weight 8
for wght in range(3,9):
    time1=time.time()
    compute_Invar_nullspace(wght,unshelve=True)
    print('nullspace of weight',wght,'computed in time',hrs_min_sec(time.time()-time1),'\n')

# %%
shape(Invar_Mats[9])

# %%
i=shape(Invar_Mats[9])[1]
A=Invar_Mats[9][0:i,0:i]
A_null=A.nullspace()

# %%
with shelve.open('Syzygies') as shelf:
    shelf['A_null']=A_null

# %%
for wght in range(9,10):
    time1=time.time()
    compute_Invar_nullspace(wght,reshelve=True)
    print('nullspace of weight',wght,'computed in time',hrs_min_sec(time.time()-time1),'\n')
