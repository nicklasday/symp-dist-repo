# %%
import unittest
from tests import test_tensor_action  # or any other test module

suite = unittest.defaultTestLoader.loadTestsFromModule(test_tensor_action)
unittest.TextTestRunner().run(suite)
# Out:
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 34.862s
#
# OK
# <unittest.runner.TextTestResult run=6 errors=0 failures=0>

# %%
import unittest

loader = unittest.TestLoader()
suite = loader.discover(start_dir='tests')  # Adjust to directory path

unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_apply_cochain_map_base (test_algebra.test_complexes.test_apply_cochain_map.TestApplyCochainMap.test_apply_cochain_map_base) ... ok
# test_apply_cochain_map_linearize (test_algebra.test_complexes.test_apply_cochain_map.TestApplyCochainMap.test_apply_cochain_map_linearize) ... ok
# test_cb_on_base (test_algebra.test_complexes.test_cb.TestCb.test_cb_on_base) ... ok
# test_cb_on_lin_combs (test_algebra.test_complexes.test_cb.TestCb.test_cb_on_lin_combs) ... ok
# test_d2_zero (test_algebra.test_complexes.test_cb.TestCb.test_d2_zero) ... ok
# test_coker_proj (test_algebra.test_complexes.test_cochain.TestCochainComplex.test_coker_proj) ... ok
# test_ker_proj (test_algebra.test_complexes.test_cochain.TestCochainComplex.test_ker_proj) ... ok
# test_wedge_add_mul (test_algebra.test_complexes.test_cochain.TestCochainComplex.test_wedge_add_mul) ... ok
# test_preim (test_algebra.test_complexes.test_preim.TestPreim.test_preim) ... ok
# ...
