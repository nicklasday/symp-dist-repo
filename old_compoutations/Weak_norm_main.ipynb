# %%
from sympy import *
# %run Geom_Prolongation.ipynb
# %run Particular_Distributions.ipynb

# %%
# ~ 15 hrs through weight 8
g=Symp_symb(7)
E=g.ext_alg
C=g.cochain_complex
D,D_JS=Weak_Prenorm_distr(g,4,unshelve=True)
P=Geom_Prolongation(D,D_JS)
# Out:
# Jacobi id of weight 1 computed in time 2.0 sec
# Jacobi id of weight 2 computed in time 3.0 sec
# Jacobi id of weight 3 computed in time 7.0 sec
# Jacobi id of weight 4 computed in time 13.0 sec

# %%
y,h,e=symbols('y,h,e')
K=IndexedBase('K')
Y,H,E,X,e1,e2,e3,e4,e5,e6,N=g.basis

# %%
F1,K1=P.normal_frame(1)
simplify_cochain(K1)
print('K1 =',K1)
# Out:
# weight 1 curvature computed in time 0.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 1.0 sec
# weight 1 differential substitutions complete in time 0.0 sec
# weight 1 normalization complete in time 2.0 sec
# K1 = 0

# %%
F2,K2=P.normal_frame(2)
simplify_cochain(K2)
print('K2 =',K2)
# Out:
# weight 2 curvature computed in time 8.0 sec
# weight 2 projection computed in time 0.0 sec
# weight 2 preimage cochain computed in time 0.0 sec
# weight 2 Matrix exponential complete in time 2.0 sec
# weight 2 differential substitutions complete in time 0.0 sec
# weight 2 normalization complete in time 11.0 sec
# K2 = 0

# %%
F3,K3=P.normal_frame(3)
simplify_cochain(K3)
# Out:
# weight 3 curvature computed in time 44.0 sec
# weight 3 projection computed in time 0.0 sec
# weight 3 preimage cochain computed in time 0.0 sec
# weight 3 Matrix exponential complete in time 3.0 sec
# weight 3 differential substitutions complete in time 1.0 sec
# weight 3 normalization complete in time 49.0 sec

# %%
F4,K4=P.normal_frame(4)
simplify_cochain(K4)
# Out:
# weight 4 curvature computed in time 1.0 min 13.0 sec
# weight 4 projection computed in time 1.0 sec
# weight 4 preimage cochain computed in time 1.0 sec
# weight 4 Matrix exponential complete in time 3.0 sec
# weight 4 differential substitutions complete in time 3.0 sec
# weight 4 normalization complete in time 1.0 min 21.0 sec

# %%
for a in [K3h,K4h]:
    display(factor(a))
# Out:
# -(442*K[3, 9, 8, 4] + 884*K[3, 9, 8]*K[5, 8, 9] + 1234*K[3, 9, 8]*K[6, 7, 9] + 210*K[5, 6, 5] - 315*K[5, 8, 7] + 210*K[6, 7, 7] + 350*K[7, 8, 9])*(3*{{e_1^*\wedge}e_4^*\otimes}e_2 + 6*{{e_1^*\wedge}e_5^*\otimes}e_3 + 5*{{e_1^*\wedge}e_6^*\otimes}e_4 - 3*{{e_2^*\wedge}e_3^*\otimes}e_2 - 3*{{e_2^*\wedge}e_4^*\otimes}e_3 + {{e_2^*\wedge}e_5^*\otimes}e_4 + 5*{{e_2^*\wedge}e_6^*\otimes}e_5 - 4*{{e_3^*\wedge}e_4^*\otimes}e_4 - 4*{{e_3^*\wedge}e_5^*\otimes}e_5 + 5*{{e_3^*\wedge}e_6^*\otimes}e_6 - 9*{{e_4^*\wedge}e_5^*\otimes}e_6)*exp(e)*exp(-h)/7560
# (5*{{X^*\wedge}e_4^*\otimes}e_1 + 8*{{X^*\wedge}e_5^*\otimes}e_2 + 5*{{X^*\wedge}e_6^*\otimes}e_3)*(175*K[3, 9, 6] - 315*K[3, 9, 8, 3, 3] + 37*K[3, 9, 8]**2)*exp(8*h)/3150

# %%
temp_dict={}
for w in C.basis(2):
    for c in C.basis(2,w):
        temp_dict[c.symb_expr()]=0
temp_dict[symbols('e')]=0
temp_dict[symbols('h')]=0

temp_dict[symbols('{{e_1^*\wedge}e_4^*\otimes}e_2')]=Rational(1,3)
temp_dict[symbols('{{X^*\wedge}e_4^*\otimes}e_1')]=Rational(1,5)
temp_dict[symbols('{{X^*\wedge}e_6^*\otimes}e_1')]=1

K3h_coeff=K3h.subs(temp_dict)
K4h_coeff=K4h.subs(temp_dict)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:10: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:10: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_11000\2762517324.py:8: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{e_1^*\wedge}e_4^*\otimes}e_2')]=Rational(1,3)
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_11000\2762517324.py:9: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{X^*\wedge}e_4^*\otimes}e_1')]=Rational(1,5)
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_11000\2762517324.py:10: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{X^*\wedge}e_6^*\otimes}e_1')]=1

# %%
for A in [K3h_coeff,K4h_coeff]:
    display(A)
# Out:
# -221*K[3, 9, 8, 4]/3780 - 221*K[3, 9, 8]*K[5, 8, 9]/1890 - 617*K[3, 9, 8]*K[6, 7, 9]/3780 - K[5, 6, 5]/36 + K[5, 8, 7]/24 - K[6, 7, 7]/36 - 5*K[7, 8, 9]/108
# K[3, 9, 6]/18 - K[3, 9, 8, 3, 3]/10 + 37*K[3, 9, 8]**2/3150

# %%
for A in [K3h_coeff,K4h_coeff]:
    print(A)
# Out:
# -221*K[3, 9, 8, 4]/3780 - 221*K[3, 9, 8]*K[5, 8, 9]/1890 - 617*K[3, 9, 8]*K[6, 7, 9]/3780 - K[5, 6, 5]/36 + K[5, 8, 7]/24 - K[6, 7, 7]/36 - 5*K[7, 8, 9]/108
# K[3, 9, 6]/18 - K[3, 9, 8, 3, 3]/10 + 37*K[3, 9, 8]**2/3150
