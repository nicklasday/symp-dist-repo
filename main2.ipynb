# %%
# %run Geom_Prolongation.ipynb
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/d8/w2604v6932b3xkhchzs64z8w0000gn/T/ipykernel_54817/1830096735.py:2: SyntaxWarning: invalid escape sequence '\w'
#   '''arg: A, a k-upper triangular matrix (k UT ==> k-1 UT, and UT <==> 0 UT)
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/d8/w2604v6932b3xkhchzs64z8w0000gn/T/ipykernel_54817/1830096735.py:2: SyntaxWarning: invalid escape sequence '\w'
#   '''arg: A, a k-upper triangular matrix (k UT ==> k-1 UT, and UT <==> 0 UT)
# <>:15: SyntaxWarning: invalid escape sequence '\w'
# <>:16: SyntaxWarning: invalid escape sequence '\o'
# /var/folders/d8/w2604v6932b3xkhchzs64z8w0000gn/T/ipykernel_54817/2267405306.py:15: SyntaxWarning: invalid escape sequence '\w'
#   s+='^*\wedge}'
# /var/folders/d8/w2604v6932b3xkhchzs64z8w0000gn/T/ipykernel_54817/2267405306.py:16: SyntaxWarning: invalid escape sequence '\o'
#   s+=sl[len(sl)-2]+'^*\otimes}'+sl[-1]

# %%
g=Symp_symb(7)
C=g.cochain_complex
P=Geom_Prolongation(g,'standard')
y,h,e=symbols('y,h,e')
K=IndexedBase('K')

# %%
P.normal_frame(3)
# Out:
# weight 1 curvature computed in time 1.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 0.0 sec
# weight 1 normalization complete in time 1.0 sec
# weight 2 curvature computed in time 15.0 sec
# weight 2 projection computed in time 0.0 sec
# weight 2 preimage cochain computed in time 4.0 sec
# weight 2 Matrix exponential complete in time 4.0 sec
# weight 2 normalization complete in time 23.0 sec
# weight 3 curvature computed in time 3.0 min 18.0 sec
# weight 3 projection computed in time 1.0 sec
# weight 3 preimage cochain computed in time 1.0 min 3.0 sec
# weight 3 Matrix exponential complete in time 1.0 min 14.0 sec
# weight 3 normalization complete in time 5.0 min 35.0 sec

# %%
def max_nz_ind(i,j):
    w=g.basis[i].wght+g.basis[j].wght
    if w>1: return -1
    if w>=g.basis[-1].wght: return len(g.basis)-1
    k=0
    while g.basis[k].wght>=w:
        k+=1
    return k-1

# %%
print(max_nz_ind(3,4)==5)
print(max_nz_ind(0,0)==-1)
print(max_nz_ind(1,2)==2)
print(max_nz_ind(4,5)==6)
print(max_nz_ind(5,6)==8)
print(max_nz_ind(5,9)==10)
