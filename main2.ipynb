# %%
from sympy import *
# %run Geom_Prolongation.ipynb
# %run Particular_Distributions.ipynb

# %%
g=Symp_symb(7)
E=g.ext_alg
C=g.cochain_complex
D,D_JS=Standard_Prenorm_distr(g,6)
P=Geom_Prolongation(D,D_JS)
y,h,e=symbols('y,h,e')
K=IndexedBase('K')
Y,H,E,X,e1,e2,e3,e4,e5,e6,N=g.basis # # ~1 hr when reshelving
# Out:
# Jacobi id of weight 1 computed in time 1.0 sec
# Jacobi id of weight 2 computed in time 1.0 sec
# Jacobi id of weight 3 computed in time 1.0 sec
# Jacobi id of weight 4 computed in time 2.0 sec
# Jacobi id of weight 5 computed in time 6.0 sec
# Jacobi id of weight 6 computed in time 15.0 sec

# %%
D0=Standard_Prenorm_distr(g,0)[0]
for i in range(len(D0.basis)):
    for j in range(i+1,len(D0.basis)):
        print('[',g.basis[i+3],g.basis[j+3],'] =',g.elt((D0.basis[i]).bracket(D0.basis[j]).vec))
    print()
# Out:
# [ X e_1 ] = e_2
# [ X e_2 ] = e_3
# [ X e_3 ] = e_4
# [ X e_4 ] = e_5
# [ X e_5 ] = e_6
# [ X e_6 ] = K[3, 9, 3]*X + K[3, 9, 4]*e_1 + K[3, 9, 5]*e_2 + K[3, 9, 6]*e_3 + K[3, 9, 7]*e_4
# [ X N ] = K[3, 10, 3]*X + K[3, 10, 4]*e_1 + K[3, 10, 5]*e_2 + K[3, 10, 6]*e_3 + K[3, 10, 7]*e_4 + K[3, 10, 8]*e_5 + K[3, 10, 9]*e_6 + K[3, 10, 10]*N
#
# [ e_1 e_2 ] = K[4, 5, 3]*X + K[4, 5, 4]*e_1 + K[4, 5, 5]*e_2
# [ e_1 e_3 ] = K[4, 6, 3]*X + K[4, 6, 4]*e_1 + K[4, 6, 5]*e_2 + K[4, 6, 6]*e_3
# [ e_1 e_4 ] = K[4, 7, 3]*X + K[4, 7, 4]*e_1 + K[4, 7, 5]*e_2 + K[4, 7, 6]*e_3 + K[4, 7, 7]*e_4
# [ e_1 e_5 ] = K[4, 8, 3]*X + K[4, 8, 4]*e_1 + K[4, 8, 5]*e_2 + K[4, 8, 6]*e_3 + K[4, 8, 7]*e_4 + K[4, 8, 8]*e_5
# [ e_1 e_6 ] =  - N
# [ e_1 N ] = K[4, 10, 3]*X + K[4, 10, 4]*e_1 + K[4, 10, 5]*e_2 + K[4, 10, 6]*e_3 + K[4, 10, 7]*e_4 + K[4, 10, 8]*e_5 + K[4, 10, 9]*e_6 + K[4, 10, 10]*N
#
# [ e_2 e_3 ] = K[5, 6, 3]*X + K[5, 6, 4]*e_1 + K[5, 6, 5]*e_2 + K[5, 6, 6]*e_3 + K[5, 6, 7]*e_4
# [ e_2 e_4 ] = K[5, 7, 3]*X + K[5, 7, 4]*e_1 + K[5, 7, 5]*e_2 + K[5, 7, 6]*e_3 + K[5, 7, 7]*e_4 + K[5, 7, 8]*e_5
# [ e_2 e_5 ] = K[5, 8, 3]*X + K[5, 8, 4]*e_1 + K[5, 8, 5]*e_2 + K[5, 8, 6]*e_3 + K[5, 8, 7]*e_4 + K[5, 8, 8]*e_5 + K[5, 8, 9]*e_6 + N
# [ e_2 e_6 ] = K[5, 9, 3]*X + K[5, 9, 4]*e_1 + K[5, 9, 5]*e_2 + K[5, 9, 6]*e_3 + K[5, 9, 7]*e_4 + K[5, 9, 8]*e_5 + K[5, 9, 9]*e_6 + K[5, 9, 10]*N
# [ e_2 N ] = K[5, 10, 3]*X + K[5, 10, 4]*e_1 + K[5, 10, 5]*e_2 + K[5, 10, 6]*e_3 + K[5, 10, 7]*e_4 + K[5, 10, 8]*e_5 + K[5, 10, 9]*e_6 + K[5, 10, 10]*N
#
# [ e_3 e_4 ] = K[6, 7, 3]*X + K[6, 7, 4]*e_1 + K[6, 7, 5]*e_2 + K[6, 7, 6]*e_3 + K[6, 7, 7]*e_4 + K[6, 7, 8]*e_5 + K[6, 7, 9]*e_6 - N
# [ e_3 e_5 ] = K[6, 8, 3]*X + K[6, 8, 4]*e_1 + K[6, 8, 5]*e_2 + K[6, 8, 6]*e_3 + K[6, 8, 7]*e_4 + K[6, 8, 8]*e_5 + K[6, 8, 9]*e_6 + K[6, 8, 10]*N
# [ e_3 e_6 ] = K[6, 9, 3]*X + K[6, 9, 4]*e_1 + K[6, 9, 5]*e_2 + K[6, 9, 6]*e_3 + K[6, 9, 7]*e_4 + K[6, 9, 8]*e_5 + K[6, 9, 9]*e_6 + K[6, 9, 10]*N
# [ e_3 N ] = K[6, 10, 3]*X + K[6, 10, 4]*e_1 + K[6, 10, 5]*e_2 + K[6, 10, 6]*e_3 + K[6, 10, 7]*e_4 + K[6, 10, 8]*e_5 + K[6, 10, 9]*e_6 + K[6, 10, 10]*N
#
# [ e_4 e_5 ] = K[7, 8, 3]*X + K[7, 8, 4]*e_1 + K[7, 8, 5]*e_2 + K[7, 8, 6]*e_3 + K[7, 8, 7]*e_4 + K[7, 8, 8]*e_5 + K[7, 8, 9]*e_6 + K[7, 8, 10]*N
# [ e_4 e_6 ] = K[7, 9, 3]*X + K[7, 9, 4]*e_1 + K[7, 9, 5]*e_2 + K[7, 9, 6]*e_3 + K[7, 9, 7]*e_4 + K[7, 9, 8]*e_5 + K[7, 9, 9]*e_6 + K[7, 9, 10]*N
# [ e_4 N ] = K[7, 10, 3]*X + K[7, 10, 4]*e_1 + K[7, 10, 5]*e_2 + K[7, 10, 6]*e_3 + K[7, 10, 7]*e_4 + K[7, 10, 8]*e_5 + K[7, 10, 9]*e_6 + K[7, 10, 10]*N
#
# [ e_5 e_6 ] = K[8, 9, 3]*X + K[8, 9, 4]*e_1 + K[8, 9, 5]*e_2 + K[8, 9, 6]*e_3 + K[8, 9, 7]*e_4 + K[8, 9, 8]*e_5 + K[8, 9, 9]*e_6 + K[8, 9, 10]*N
# [ e_5 N ] = K[8, 10, 3]*X + K[8, 10, 4]*e_1 + K[8, 10, 5]*e_2 + K[8, 10, 6]*e_3 + K[8, 10, 7]*e_4 + K[8, 10, 8]*e_5 + K[8, 10, 9]*e_6 + K[8, 10, 10]*N
#
# [ e_6 N ] = K[9, 10, 3]*X + K[9, 10, 4]*e_1 + K[9, 10, 5]*e_2 + K[9, 10, 6]*e_3 + K[9, 10, 7]*e_4 + K[9, 10, 8]*e_5 + K[9, 10, 9]*e_6 + K[9, 10, 10]*N

# %%
# Approx. 2 min.

F1,K1=P.normal_frame(1)
simplify_cochain(K1)
F2,K2=P.normal_frame(2)
simplify_cochain(K2)
F3,K3=P.normal_frame(3)
simplify_cochain(K3)
F4,K4=P.normal_frame(4)
simplify_cochain(K4)
F5,K5=P.normal_frame(5)
F6,K6=P.normal_frame(6)

K3_subbed=ds_subs(K3,D_JS,D)
K4_subbed=ds_subs(K4,D_JS,D)
K5_subbed=ds_subs(K5,D_JS,D)
K6_subbed=ds_subs(K6,D_JS,D)

K3h=simplify(C.subspace_proj(K3_subbed,'harmonic').symb_expr())
K4h=simplify(C.subspace_proj(K4_subbed,'harmonic').symb_expr()-K3h)
K5h=simplify(C.subspace_proj(K5_subbed,'harmonic').symb_expr()-K3h-K4h)
K6h=simplify(C.subspace_proj(K6_subbed,'harmonic').symb_expr()-K3h-K4h-K5h)
# Out:
# weight 1 curvature computed in time 0.0 sec
# weight 1 projection computed in time 0.0 sec
# weight 1 preimage cochain computed in time 0.0 sec
# weight 1 Matrix exponential complete in time 1.0 sec
# weight 1 differential substitutions complete in time 0.0 sec
# weight 1 normalization complete in time 2.0 sec
# weight 2 curvature computed in time 3.0 sec
# weight 2 projection computed in time 0.0 sec
# weight 2 preimage cochain computed in time 0.0 sec
# weight 2 Matrix exponential complete in time 2.0 sec
# weight 2 differential substitutions complete in time 0.0 sec
# weight 2 normalization complete in time 6.0 sec
# weight 3 curvature computed in time 7.0 sec
# weight 3 projection computed in time 0.0 sec
# weight 3 preimage cochain computed in time 0.0 sec
# weight 3 Matrix exponential complete in time 2.0 sec
# weight 3 differential substitutions complete in time 0.0 sec
# weight 3 normalization complete in time 9.0 sec
# weight 4 curvature computed in time 9.0 sec
# weight 4 projection computed in time 0.0 sec
# weight 4 preimage cochain computed in time 0.0 sec
# weight 4 Matrix exponential complete in time 1.0 sec
# weight 4 differential substitutions complete in time 0.0 sec
# weight 4 normalization complete in time 11.0 sec
# weight 5 curvature computed in time 13.0 sec
# weight 5 projection computed in time 0.0 sec
# weight 5 preimage cochain computed in time 0.0 sec
# weight 5 Matrix exponential complete in time 1.0 sec
# weight 5 differential substitutions complete in time 0.0 sec
# weight 5 normalization complete in time 15.0 sec
# weight 6 curvature computed in time 14.0 sec
# weight 6 projection computed in time 1.0 sec
# weight 6 preimage cochain computed in time 1.0 sec
# weight 6 Matrix exponential complete in time 4.0 sec
# weight 6 differential substitutions complete in time 1.0 sec
# weight 6 normalization complete in time 21.0 sec

# %%
# # ~ 45 min
F7,K7=P.normal_frame(7)
F8,K8=P.normal_frame(8)
F9,K9=P.normal_frame(9)
# Out:
# weight 7 curvature computed in time 1.0 min 58.0 sec
# weight 7 projection computed in time 6.0 sec
# weight 7 preimage cochain computed in time 3.0 sec
# weight 7 Matrix exponential complete in time 7.0 sec
# weight 7 differential substitutions complete in time 2.0 min 13.0 sec
# weight 7 normalization complete in time 4.0 min 26.0 sec
# weight 8 curvature computed in time 4.0 min 28.0 sec
# weight 8 projection computed in time 16.0 sec
# weight 8 preimage cochain computed in time 2.0 sec
# weight 8 Matrix exponential complete in time 4.0 sec
# weight 8 differential substitutions complete in time 8.0 min 44.0 sec
# weight 8 normalization complete in time 13.0 min 34.0 sec
# weight 9 curvature computed in time 4.0 min 36.0 sec
# weight 9 projection computed in time 33.0 sec
# weight 9 preimage cochain computed in time 0.0 sec
# deg 1 wght 9 has shape (0, 1)
# weight 9 Matrix exponential complete in time 0.0 sec
# weight 9 differential substitutions complete in time 21.0 min 60.0 sec
# weight 9 normalization complete in time 27.0 min 10.0 sec

# %%
temp_dict={}
for w in C.basis(2):
    for c in C.basis(2,w):
        temp_dict[c.symb_expr()]=0

temp_dict[symbols('{{e_1^*\wedge}e_4^*\otimes}e_2')]=Rational(1,3)
temp_dict[symbols('{{X^*\wedge}e_4^*\otimes}e_1')]=Rational(1,5)
temp_dict[symbols('{{X^*\wedge}e_6^*\otimes}e_1')]=1

K3h_coeff=K3h.subs(temp_dict)
K4h_coeff=K4h.subs(temp_dict)
K6h_coeff=K6h.subs(temp_dict)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_27968\767813457.py:6: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{e_1^*\wedge}e_4^*\otimes}e_2')]=Rational(1,3)
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_27968\767813457.py:7: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{X^*\wedge}e_4^*\otimes}e_1')]=Rational(1,5)
# C:\Users\ncday.AUTH\AppData\Local\Temp\ipykernel_27968\767813457.py:8: SyntaxWarning: invalid escape sequence '\w'
#   temp_dict[symbols('{{X^*\wedge}e_6^*\otimes}e_1')]=1

# %%
K2
# Out:
# 0

# %%
display(K3h)
display(K4h)
display(K6h)
# Out:
# (3*{{e_1^*\wedge}e_4^*\otimes}e_2 + 6*{{e_1^*\wedge}e_5^*\otimes}e_3 + 5*{{e_1^*\wedge}e_6^*\otimes}e_4 - 3*{{e_2^*\wedge}e_3^*\otimes}e_2 - 3*{{e_2^*\wedge}e_4^*\otimes}e_3 + {{e_2^*\wedge}e_5^*\otimes}e_4 + 5*{{e_2^*\wedge}e_6^*\otimes}e_5 - 4*{{e_3^*\wedge}e_4^*\otimes}e_4 - 4*{{e_3^*\wedge}e_5^*\otimes}e_5 + 5*{{e_3^*\wedge}e_6^*\otimes}e_6 - 9*{{e_4^*\wedge}e_5^*\otimes}e_6)*exp(e - h)*K[4, 8, 6]/6
# (5*{{X^*\wedge}e_4^*\otimes}e_1 + 8*{{X^*\wedge}e_5^*\otimes}e_2 + 5*{{X^*\wedge}e_6^*\otimes}e_3)*exp(8*h)*K[3, 9, 6]/18
# {{X^*\wedge}e_6^*\otimes}e_1*(18*K[3, 9, 4] - 5*K[3, 9, 6, 3, 3])*exp(12*h)/18

# %% [markdown]
# ## Syzygies

# %%
from itertools import combinations_with_replacement
I=IndexedBase('I')
W=IndexedBase('W')
Abstract_Invars={} # keys are weights; values are abstract invariants
Concrete_Invars={I[3]:K3h_coeff,W[4]:K4h_coeff,W[6]:K6h_coeff} # keys are homogeneous invar monomials; vals are the corresponding concrete invars
Harm_Invars={} # keys are weights; values are (abstract_invar,concrete_invar)
Invar_Mats={} # keys are weights; values are mats with cols giving the coords of concrete invars in the concrete monomial basis
Invar_nullspaces={} # keys are weights; values are the nullspaces of the above matrices
Concrete_monom_basis={} # keys are weights; values are lists of monomials which span the concrete invariants in the weight

fundamental_invars=[I[3],W[4],W[6]]

# %%
def coordinatize_in_monom_basis(expr1,basis):
    """Returns the coordinates of expr in the given basis as a list
    INPUTS:
    * 'expr' - a linear combination of the monomials from basis
    * 'basis' - a list of monomials in symbols and Indexed objects"""
    r=[0]*len(basis)
    expr=expand(expr1)
    cd=expr.as_coefficients_dict()
    for i in range(len(basis)):
        r[i]=cd[basis[i]]
    return r

def monomials_in_expr(expr1):
    """Returns the set of all monomials involved in expr, which should be a polynomial over R
    INPUTS:
    * 'expr' - a polynomial in symbols and Indexed objects over R"""
    # r=set()
    expr=expand(expr1)
    return set(expand(expr).as_coefficients_dict().keys())
    # if isinstance(expr,numbers.Number): return r
    # if type(expr)==Add:
    #     for A in expr.args:
    #         r=r.union(monomials_in_expr(A))
    # if type(expr) in [Mul, Pow]:
    #     temp=expr.as_coeff_Mul()[1]
    #     r.add(temp)
    # if type(expr) in [Indexed,Symbol]:
    #     r.add(expr)
    # return r

def higher_der(expr,*ders):
    r=expr
    for i in ders:
        r=P.dir_der(r,F9.col(i))
    return r

def coeff_add_to_monom_dict(ca):
    r={}
    for A in ca:
        r[A.as_coeff_Mul()[1]]=A.as_coeff_Mul()[0]
    return r

def common_monom(d1,d2):
    return set(d1.keys()).intersection(set(d2.keys()))

# %%
## collect_some might speed up the process of taking abnormal derivatives

import heapq

def incr_key(d,k):
    """d-dict, k-key; increments value at k or makes d[k]=1"""
    if k in d:
        d[k]=d[k]+1
    else: d[k]=1

def count_terms(expr):
    """A heuristic count of what terms show up a lot in the polynomial expr"""
    r={}
    count_terms_rec(expr,r)
    return r

def count_terms_rec(expr,count_dict):
    if isinstance(expr,numbers.Number): return None
    if type(expr) in [Add,Mul]:
        for a in expr.args: count_terms_rec(a,count_dict)
    if type(expr)==Pow: count_terms_rec(expr.base,count_dict)
    if type(expr) in [Indexed,Symbol]: incr_key(count_dict,expr)

def top_k_keys(d, k):
    if k <= 0:
        return []

    # Create a min-heap to store the top k keys, including their original order
    min_heap = []

    for index, (key, value) in enumerate(d.items()):
        # Push a tuple of (value, original index, key) onto the heap
        heapq.heappush(min_heap, (value, index, key))
        # If the heap size exceeds k, pop the smallest element
        if len(min_heap) > k:
            heapq.heappop(min_heap)

    # Extract the keys from the heap, sorting them by values and original index
    top_keys = [key for _, _, key in sorted(min_heap, key=lambda x: (-x[0], x[1]))]
    
    return top_keys

def collect_some(expr):
    """Chooses some frequently occurring terms in the polynomial expr and collects those terms"""
    ## Count occurrences
    terms=count_terms(expr)
    if terms=={}: return copy.copy(expr)
    total_terms = sum(terms.values()) # use this to decide how many terms to collect
    num_terms=log(total_terms,10) # This is an arbitrary choice
    collect_terms=top_k_keys(terms,num_terms)

    r=copy.copy(expr)
    collect(r,collect_terms)
    return r

# %%
def all_partitions(s,Z):
    """Returns the set of all tuples (d1,d2,...dj) so that z1*d1 + ... + zj*dj=s
    where Z={z1,z2,...zj}
    INPUTS:
    * 's' - a natural number
    * 'Z' - a finite list of distinct natural numbers (without 0)"""

    if s==0: return {tuple([0]*len(Z))}
    if s<0: return set()
    if len(Z)==0:
        return set()
    
    r=set()
    for a in range(s//Z[0]+1):
        new_Z=copy.copy(Z)
        new_Z.remove(Z[0])
        r=r.union({tuple([a]+list(A)) for A in all_partitions(s-a*Z[0],new_Z)})
    return r

def multiply_cart_prod_elts(L):
    r1,r2=1,1
    for a in L:
        a1=[b[0] for b in a]
        a2=[b[1] for b in a]
        r1=r1*prod(a1)
        r2=r2*prod(a2)
    return (r1,r2)

def Compute_abstract_invars(wght,additional_invars,reshelve=False,unshelve=False):
    """Adds invariants to Abstract_Invars of the given weight by taking derivatives and
    products of previous abstract invariants and by adding the given set of additional invariants.
    Assumes invariants of lower weights have already been computed.
    INPUTS:
    * 'wght' - a natural number weight
    * 'additional_invar' - a set of invariants as pairs (Indexed,expr) (for example {(W[4],5*K[3,9,6]/18)})
    """
    if unshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                Abstract_Invars[wght]=shelf['Standard_norm_Abstract_Invars'+'{j}'.format(j=wght)]
                return None
        except: pass

    # additional invariants
    Abs_candidates={A for A in additional_invars}

    # derivatives of previous invariants
    if wght-1 in Abstract_Invars:
        HI=list(Abstract_Invars[wght-1])
        for invar in HI:
            Abs_candidates=Abs_candidates.union(monomials_in_expr(D.abn_ind_der(invar,3)))
            Abs_candidates=Abs_candidates.union(monomials_in_expr(D.abn_ind_der(invar,4)))
    
    # products of previous invariants
    # The below block is wrong!
    for p in all_partitions(wght,list(range(3,wght))):
        big_list=[list(combinations_with_replacement(Abstract_Invars[list(range(3,wght))[i]],p[i])) for i in range(len(p))]
        p_prods=list(itertools.product(*big_list))
        for pp in p_prods:
            Abs_candidates.add(prod([prod(a) for a in pp]))
    
    Abs_candidates=list(Abs_candidates)

    temp_basis=set()
    for invar in Abs_candidates:
        temp_basis=temp_basis.union(monomials_in_expr(invar))
    temp_basis=list(temp_basis)

    A=zeros(len(temp_basis),0)
    for invar in Abs_candidates:
        A=A.col_insert(shape(A)[1],Matrix(coordinatize_in_monom_basis(invar,temp_basis)))
    pivs=A.rref()[1]
    Abstract_Invars[wght]=[Abs_candidates[i] for i in pivs]

    if reshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                shelf['Standard_norm_Abstract_Invars'+'{j}'.format(j=wght)]=Abstract_Invars[wght]
        except: print('Reshelving of harm_invars in wght',wght,'Failed')

def Compute_concrete_invars(wght,conc_dict,reshelve=False,unshelve=False):
    """Converts the abstract invariants of weight wght to concrete invariants,
    storing the results in conc_dict, assuming Abstract_Invars[wght] has been computed
    
    WARNING: Unshelving here isn't subdivided by weight, so whatever weight was shelved will be restored,
    overwriting those weights already computed."""
    if unshelve:
        with shelve.open('harm_invars') as shelf:
                conc_dict=shelf['Standard_norm_Concrete_Invars']
                return None
                # for invar in shelf['Standard_norm_conc_dict']:
                #     conc_dict[invar]=shelf['Standard_norm_Concrete_Invars'][Invar]

    for invar in Abstract_Invars[wght]:
        if invar not in fundamental_invars:
            # Products of previous invars
            if len(invar.as_coeff_mul()[1])>1: 
                temp_subs={a:conc_dict[a] for a in invar.as_coeff_mul()[1]}
                r=invar.xreplace(temp_subs)
            # Products of previous invars
            elif type(invar.as_coeff_mul()[1][0])==Pow:
                temp_subs={invar.as_coeff_mul()[1][0].as_base_exp()[0]:conc_dict[invar.as_coeff_mul()[1][0].as_base_exp()[0]]}
                r=invar.xreplace(temp_subs)
            # Derivative of previous invar
            else:
                collected=collect_some(conc_dict[invar.base[invar.indices[0:-1]]])
                r=ds_subs(P.dir_der(collected,F9.col(invar.indices[-1])),D_JS,D)
            conc_dict[invar]=r

    if reshelve:
        try:
            with shelve.open('harm_invars') as shelf:
                shelf['Standard_norm_Concrete_Invars']=conc_dict
        except: pass

# %%
Abstract_Invars={}
new_Invars={3:{I[3]},4:{W[4]},5:set(),6:{W[6]},7:set(),8:set(),9:set()}
for i in range(3,10):
    Compute_abstract_invars(i,new_Invars[i],unshelve=True)

# %%
# # ~ 7 hrs.
Concrete_Invars={I[3]:K3h_coeff,W[4]:K4h_coeff,W[6]:K6h_coeff} # keys are homogeneous invar monomials; vals are the corresponding concrete invars

for i in range(3,10):
    time0=time.time()
    Compute_concrete_invars(i,Concrete_Invars)
    print('Weights',i,'computed in time',hrs_min_sec(time.time()-time0))
# Out:
# Weights 3 computed in time 0.0 sec
# Weights 4 computed in time 0.0 sec
# Weights 5 computed in time 0.0 sec
# Weights 6 computed in time 2.0 sec
# Weights 7 computed in time 19.0 sec
# Weights 8 computed in time 5.0 min 15.0 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[178], line 6
#       4 for i in range(3,10):
#       5     time0=time.time()
# ----> 6     Compute_concrete_invars(i,Concrete_Invars)
#       7     print('Weights',i,'computed in time',hrs_min_sec(time.time()-time0))
#
# Cell In[176], line 107, in Compute_concrete_invars(wght, conc_dict, reshelve, unshelve)
#     104         # Derivative of previous invar
#     105         else:
#     106             collected=collect_some(conc_dict[invar.base[invar.indices[0:-1]]])
# --> 107             r=ds_subs(P.dir_der(collected,F9.col(invar.indices[-1])),D_JS,D)
#     108         conc_dict[invar]=r
#     110 if reshelve:
#
# File ~\AppData\Local\Temp\ipykernel_27128\1337004037.py:61, in Geom_Prolongation.dir_der(self, f, v)
#      59 dy=diff(f,y)
#      60 dh=diff(f,h) # It's slightly inefficient to compute these every time, but not a huge deal (probably)
# ---> 61 de=diff(f,e)
#      63 der_vec=[dy,dh,de]+[0]*(len(self.alg.basis)-3)
#      64 for i in range(3,len(v)):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:2482, in diff(f, *symbols, **kwargs)
#    2418 """
#    2419 Differentiate f with respect to symbols.
#    2420
#    (...)
#    2479
#    2480 """
#    2481 if hasattr(f, 'diff'):
# -> 2482     return f.diff(*symbols, **kwargs)
#    2483 kwargs.setdefault('evaluate', True)
#    2484 return _derivative_dispatch(f, *symbols, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\expr.py:3586, in Expr.diff(self, *symbols, **assumptions)
#    3584 def diff(self, *symbols, **assumptions):
#    3585     assumptions.setdefault("evaluate", True)
# -> 3586     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1909, in _derivative_dispatch(expr, *variables, **kwargs)
#    1907     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1908     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1909 return Derivative(expr, *variables, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1437, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1430     if not old_v.is_scalar and not hasattr(
#    1431             old_v, '_eval_derivative'):
#    1432         # special hack providing evaluation for classes
#    1433         # that have defined is_scalar=True but have no
#    1434         # _eval_derivative defined
#    1435         expr *= old_v.diff(old_v)
# -> 1437 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1438 if obj is not None and obj.is_zero:
#    1439     return obj
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1898, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1892 @classmethod
#    1893 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1894     # Evaluate the derivative `n` times.  If
#    1895     # `_eval_derivative_n_times` is not overridden by the current
#    1896     # object, the default in `Basic` will call a loop over
#    1897     # `_eval_derivative`:
# -> 1898     return expr._eval_derivative_n_times(v, count)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1871, in Basic._eval_derivative_n_times(self, s, n)
#    1869 obj = self
#    1870 for i in range(n):
# -> 1871     obj2 = obj._eval_derivative(s)
#    1872     if obj == obj2 or obj2 is None:
#    1873         break
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\add.py:507, in Add._eval_derivative(self, s)
#     505 @cacheit
#     506 def _eval_derivative(self, s):
# --> 507     return self.func(*[a.diff(s) for a in self.args])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\expr.py:3586, in Expr.diff(self, *symbols, **assumptions)
#    3584 def diff(self, *symbols, **assumptions):
#    3585     assumptions.setdefault("evaluate", True)
# -> 3586     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1909, in _derivative_dispatch(expr, *variables, **kwargs)
#    1907     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1908     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1909 return Derivative(expr, *variables, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1437, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1430     if not old_v.is_scalar and not hasattr(
#    1431             old_v, '_eval_derivative'):
#    1432         # special hack providing evaluation for classes
#    1433         # that have defined is_scalar=True but have no
#    1434         # _eval_derivative defined
#    1435         expr *= old_v.diff(old_v)
# -> 1437 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1438 if obj is not None and obj.is_zero:
#    1439     return obj
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1898, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1892 @classmethod
#    1893 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1894     # Evaluate the derivative `n` times.  If
#    1895     # `_eval_derivative_n_times` is not overridden by the current
#    1896     # object, the default in `Basic` will call a loop over
#    1897     # `_eval_derivative`:
# -> 1898     return expr._eval_derivative_n_times(v, count)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\mul.py:986, in Mul._eval_derivative_n_times(self, s, n)
#     984 from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#     985 for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 986     p = Mul(*[arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     987     terms.append(c * p)
#     988 return Add(*terms)
#
#     [... skipping similar frames: Derivative.__new__ at line 1437 (1 times), _derivative_dispatch at line 1909 (1 times), Derivative._dispatch_eval_derivative_n_times at line 1898 (1 times), Expr.diff at line 3586 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1871, in Basic._eval_derivative_n_times(self, s, n)
#    1869 obj = self
#    1870 for i in range(n):
# -> 1871     obj2 = obj._eval_derivative(s)
#    1872     if obj == obj2 or obj2 is None:
#    1873         break
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\add.py:507, in Add._eval_derivative(self, s)
#     505 @cacheit
#     506 def _eval_derivative(self, s):
# --> 507     return self.func(*[a.diff(s) for a in self.args])
#
#     [... skipping similar frames: Derivative.__new__ at line 1437 (1 times), _derivative_dispatch at line 1909 (1 times), Derivative._dispatch_eval_derivative_n_times at line 1898 (1 times), Expr.diff at line 3586 (1 times), __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\mul.py:986, in Mul._eval_derivative_n_times(self, s, n)
#     984 from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#     985 for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 986     p = Mul(*[arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     987     terms.append(c * p)
#     988 return Add(*terms)
#
#     [... skipping similar frames: Derivative.__new__ at line 1437 (3 times), _derivative_dispatch at line 1909 (3 times), Derivative._dispatch_eval_derivative_n_times at line 1898 (3 times), Expr.diff at line 3586 (3 times), __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (2 times), Add._eval_derivative at line 507 (1 times), Basic._eval_derivative_n_times at line 1871 (1 times), Mul._eval_derivative_n_times at line 986 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1871, in Basic._eval_derivative_n_times(self, s, n)
#    1869 obj = self
#    1870 for i in range(n):
# -> 1871     obj2 = obj._eval_derivative(s)
#    1872     if obj == obj2 or obj2 is None:
#    1873         break
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\add.py:507, in Add._eval_derivative(self, s)
#     505 @cacheit
#     506 def _eval_derivative(self, s):
# --> 507     return self.func(*[a.diff(s) for a in self.args])
#
#     [... skipping similar frames: _derivative_dispatch at line 1909 (1 times), Expr.diff at line 3586 (1 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1437, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1430     if not old_v.is_scalar and not hasattr(
#    1431             old_v, '_eval_derivative'):
#    1432         # special hack providing evaluation for classes
#    1433         # that have defined is_scalar=True but have no
#    1434         # _eval_derivative defined
#    1435         expr *= old_v.diff(old_v)
# -> 1437 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1438 if obj is not None and obj.is_zero:
#    1439     return obj
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1898, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1892 @classmethod
#    1893 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1894     # Evaluate the derivative `n` times.  If
#    1895     # `_eval_derivative_n_times` is not overridden by the current
#    1896     # object, the default in `Basic` will call a loop over
#    1897     # `_eval_derivative`:
# -> 1898     return expr._eval_derivative_n_times(v, count)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\mul.py:986, in Mul._eval_derivative_n_times(self, s, n)
#     984 from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#     985 for kvals, c in multinomial_coefficients_iterator(m, n):
# --> 986     p = Mul(*[arg.diff((s, k)) for k, arg in zip(kvals, args)])
#     987     terms.append(c * p)
#     988 return Add(*terms)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\expr.py:3586, in Expr.diff(self, *symbols, **assumptions)
#    3584 def diff(self, *symbols, **assumptions):
#    3585     assumptions.setdefault("evaluate", True)
# -> 3586     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1909, in _derivative_dispatch(expr, *variables, **kwargs)
#    1907     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1908     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1909 return Derivative(expr, *variables, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\function.py:1462, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     expr = obj
#    1461 # what we have so far can be made canonical
# -> 1462 expr = expr.replace(
#    1463     lambda x: isinstance(x, Derivative),
#    1464     lambda x: x.canonical)
#    1466 if unhandled:
#    1467     if isinstance(expr, Derivative):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1666, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1663             expr = v
#    1664     return expr
# -> 1666 rv = walk(self, rec_replace)
#    1667 return (rv, mapping) if map else rv
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1641, in Basic.replace.<locals>.walk(rv, F)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1641, in Basic.replace.<locals>.walk(rv, F)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
#     [... skipping similar frames: Basic.replace.<locals>.walk at line 1641 (4 times)]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1641, in Basic.replace.<locals>.walk(rv, F)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:1638, in Basic.replace.<locals>.walk(rv, F)
#    1635 def walk(rv, F):
#    1636     """Apply ``F`` to args and then to result.
#    1637     """
# -> 1638     args = getattr(rv, 'args', None)
#    1639     if args is not None:
#    1640         if args:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sympy\core\basic.py:786, in Basic.args(self)
#     762     """
#     763     The top-level function in an expression.
#     764
#    (...)
#     782
#     783     """
#     784     return self.__class__
# --> 786 @property
#     787 def args(self) -> tuple[Basic, ...]:
#     788     """Returns a tuple of arguments of 'self'.
#     789
#     790     Examples
#    (...)
#     814     change the interface in the future if needed).
#     815     """
#     816     return self._args
#
# KeyboardInterrupt:

# %%
with shelve.open('harm_invars') as shelf:
    shelf['Standard_norm_Concrete_Invars'+len(g.basis)]=Concrete_Invars

# %% [markdown]
# #### Construct Monomial Bases

# %%
for i in range(3,10):
    print(len(Abstract_Invars[i]))
# Out:
# 1
# 3
# 6
# 14
# 29
# 64
# 136

# %%
## Approx. 2 min.
monom_sets={}
for i in range(3,10):
    counter=0
    print( '-------------------------Weight',i,'-------------------------')
    for A in Abstract_Invars[i]:
        time0=time.time()
        monom_sets[A]=monomials_in_expr(Concrete_Invars[A])
        counter+=1
        print(counter,'of',len(Abstract_Invars[i]),'complete in time',hrs_min_sec(time.time()-time0))
# Out:
# -------------------------Weight 3 -------------------------
# 1 of 1 complete in time 0.0 sec
# -------------------------Weight 4 -------------------------
# 1 of 3 complete in time 0.0 sec
# 2 of 3 complete in time 0.0 sec
# 3 of 3 complete in time 0.0 sec
# -------------------------Weight 5 -------------------------
# 1 of 6 complete in time 0.0 sec
# 2 of 6 complete in time 0.0 sec
# 3 of 6 complete in time 0.0 sec
# 4 of 6 complete in time 0.0 sec
# 5 of 6 complete in time 0.0 sec
# 6 of 6 complete in time 0.0 sec
# -------------------------Weight 6 -------------------------
# 1 of 14 complete in time 0.0 sec
# 2 of 14 complete in time 0.0 sec
# 3 of 14 complete in time 0.0 sec
# 4 of 14 complete in time 0.0 sec
# 5 of 14 complete in time 0.0 sec
# 6 of 14 complete in time 0.0 sec
# 7 of 14 complete in time 0.0 sec
# 8 of 14 complete in time 0.0 sec
# 9 of 14 complete in time 0.0 sec
# 10 of 14 complete in time 0.0 sec
# 11 of 14 complete in time 0.0 sec
# 12 of 14 complete in time 0.0 sec
# 13 of 14 complete in time 0.0 sec
# 14 of 14 complete in time 0.0 sec
# -------------------------Weight 7 -------------------------
# 1 of 29 complete in time 0.0 sec
# 2 of 29 complete in time 0.0 sec
# 3 of 29 complete in time 0.0 sec
# 4 of 29 complete in time 0.0 sec
# 5 of 29 complete in time 0.0 sec
# 6 of 29 complete in time 0.0 sec
# 7 of 29 complete in time 0.0 sec
# 8 of 29 complete in time 0.0 sec
# 9 of 29 complete in time 0.0 sec
# 10 of 29 complete in time 0.0 sec
# 11 of 29 complete in time 0.0 sec
# 12 of 29 complete in time 0.0 sec
# 13 of 29 complete in time 0.0 sec
# 14 of 29 complete in time 0.0 sec
# 15 of 29 complete in time 0.0 sec
# 16 of 29 complete in time 0.0 sec
# 17 of 29 complete in time 0.0 sec
# 18 of 29 complete in time 0.0 sec
# 19 of 29 complete in time 0.0 sec
# 20 of 29 complete in time 0.0 sec
# 21 of 29 complete in time 0.0 sec
# 22 of 29 complete in time 0.0 sec
# 23 of 29 complete in time 0.0 sec
# 24 of 29 complete in time 0.0 sec
# 25 of 29 complete in time 0.0 sec
# 26 of 29 complete in time 0.0 sec
# 27 of 29 complete in time 0.0 sec
# 28 of 29 complete in time 0.0 sec
# 29 of 29 complete in time 0.0 sec
# -------------------------Weight 8 -------------------------
# 1 of 64 complete in time 0.0 sec
# 2 of 64 complete in time 0.0 sec
# 93 of 136 complete in time 0.0 sec
# 94 of 136 complete in time 3.0 sec
# 95 of 136 complete in time 4.0 sec
# 96 of 136 complete in time 0.0 sec
# 97 of 136 complete in time 0.0 sec
# 98 of 136 complete in time 0.0 sec
# 99 of 136 complete in time 0.0 sec
# 100 of 136 complete in time 2.0 sec
# 101 of 136 complete in time 0.0 sec
# 102 of 136 complete in time 3.0 sec
# 103 of 136 complete in time 3.0 sec
# 104 of 136 complete in time 0.0 sec
# 105 of 136 complete in time 2.0 sec
# 106 of 136 complete in time 3.0 sec
# 107 of 136 complete in time 3.0 sec
# 108 of 136 complete in time 0.0 sec
# 109 of 136 complete in time 0.0 sec
# 110 of 136 complete in time 3.0 sec
# 111 of 136 complete in time 0.0 sec
# 112 of 136 complete in time 0.0 sec
# 113 of 136 complete in time 0.0 sec
# 114 of 136 complete in time 3.0 sec
# 115 of 136 complete in time 0.0 sec
# 116 of 136 complete in time 4.0 sec
# 117 of 136 complete in time 3.0 sec
# 118 of 136 complete in time 0.0 sec
# 119 of 136 complete in time 0.0 sec
# 120 of 136 complete in time 1.0 sec
# 121 of 136 complete in time 0.0 sec
# 122 of 136 complete in time 0.0 sec
# 123 of 136 complete in time 0.0 sec
# 124 of 136 complete in time 3.0 sec
# 125 of 136 complete in time 0.0 sec
# 126 of 136 complete in time 2.0 sec
# 127 of 136 complete in time 0.0 sec
# 128 of 136 complete in time 2.0 sec
# 129 of 136 complete in time 0.0 sec
# 130 of 136 complete in time 2.0 sec
# 131 of 136 complete in time 4.0 sec
# 132 of 136 complete in time 0.0 sec
# 133 of 136 complete in time 0.0 sec
# 134 of 136 complete in time 3.0 sec
# 135 of 136 complete in time 0.0 sec
# 136 of 136 complete in time 0.0 sec

# %%
monom_bases={}
for i in range(3,10):
    time0=time.time()
    temp=set()
    for A in Abstract_Invars[i]:
        temp=temp.union(monom_sets[A])
    monom_bases[i]=list(temp)

# %%
for i in range(3,10):
    print(len(monom_bases[i]))
# Out:
# 1
# 10
# 44
# 173
# 616
# 1965
# 5842

# %% [markdown]
# ### Coordinatize in Monomial Bases

# %%
from sympy.polys.matrices import DomainMatrix

# %%
Invar_Dom_Mats={}
for wght in range(3,10):
    Invar_Dom_Mats[wght]=DomainMatrix.from_Matrix(Invar_Mats[wght])

# %%
Invar_Mats={}
for wght in range(3,10):
    time0=time.time()
    temp=zeros(len(monom_bases[wght]),0)
    for A in Abstract_Invars[wght]:
        temp=temp.col_insert(shape(temp)[1],Matrix(coordinatize_in_monom_basis(Concrete_Invars[A],monom_bases[wght])))
    Invar_Mats[wght]=temp
    print(wght,'-->',hrs_min_sec(time.time()-time0))
# Out:
# 3 --> 0.0 sec
# 4 --> 0.0 sec
# 5 --> 0.0 sec
# 6 --> 0.0 sec
# 7 --> 0.0 sec
# 8 --> 1.0 sec
# 9 --> 12.0 sec

# %% [markdown]
# ### Compute Nullspaces

# %%
Syzygy_spaces={}
for wght in range(3,10):
    Syzygy_spaces[wght]=(Invar_Dom_Mats[wght].nullspace()).to_Matrix()

# %%
Syzygies={}
for w in range(3,10):
    Syzygies[w]=[]
    print('\nWEIGHT', w)
    temp=Syzygy_spaces[w]*Matrix(Abstract_Invars[w])
    Syzygies[w]=[temp[i,0] for i in range(shape(temp)[0])]
    for s in Syzygies[w]:print(s)
# Out:
# WEIGHT 3
#
# WEIGHT 4
#
# WEIGHT 5
# 7*I[3, 3, 3] + W[4, 4]
#
# WEIGHT 6
# I[3, 3, 3, 3] + W[4, 4, 3]/7
# I[3, 3, 3, 4] + W[4, 4, 4]/7
#
# WEIGHT 7
# 7*I[3, 3, 3, 3, 4] + W[4, 4, 3, 4]
# I[3, 3, 3, 4, 3] + W[4, 4, 4, 3]/7
# 7*I[3, 3, 3, 4, 4] + W[4, 4, 4, 4]
# 7*I[3, 3, 3, 3, 3] + W[4, 4, 3, 3]
# 14*I[3, 3, 3, 3, 4] + W[4, 3, 4, 4] + W[4, 4, 4, 3]
#
# WEIGHT 8
# I[3, 3, 3, 4, 4, 3] + W[4, 4, 4, 4, 3]/7
# -I[3, 3, 3, 3, 4, 4]/2 + I[3, 3, 3, 4, 3, 4] + W[4, 4, 4, 4, 3]/14
# 7*I[3, 3, 3]*I[3] + I[3]*W[4, 4]
# -W[4, 3, 4, 4, 3]/2 + W[4, 4, 3, 4, 3] - W[4, 4, 4, 3, 3]/2
# I[3, 3, 3, 4, 3, 3] + W[4, 4, 4, 3, 3]/7
# I[3, 3, 3, 3, 4, 3] + W[4, 3, 4, 4, 3]/14 + W[4, 4, 4, 3, 3]/14
# 7*I[3, 3, 3, 3, 4, 4]/2 + W[4, 4, 4, 3, 4] - W[4, 4, 4, 4, 3]/2
# I[3, 3, 3, 3, 3, 3] + W[4, 4, 3, 3, 3]/7
# I[3, 3, 3, 4, 4, 4] + W[4, 4, 4, 4, 4]/7
# 7*I[3, 3, 3, 3, 3, 4] + W[4, 4, 3, 3, 4]
# 7*I[3, 3, 3, 3, 4, 4] + W[4, 4, 3, 4, 4]
# -16*I[3, 4]*W[4]/3 - W[4, 3, 3, 4, 4]/2 + W[4, 3, 4, 3, 4] - W[4, 3, 4, 4, 3]/2
# 2640*I[3, 3]*W[4]/7 + 330*I[3]*W[4, 3]/7 + 55*W[4, 3, 3, 3, 4]/12 - 275*W[4, 3, 3, 4, 3]/14 + 825*W[4, 3, 4, 3, 3]/28 - 110*W[4, 4, 3, 3, 3]/7 - 7*W[6, 3, 4]/12 + W[6, 4, 3]
# 21*I[3, 3, 3, 3, 4, 4]/2 + W[4, 3, 4, 4, 4] + W[4, 4, 4, 4, 3]/2
#
# WEIGHT 9
# I[3, 3, 3, 4, 3, 3, 4] + W[4, 4, 4, 3, 3, 4]/7
# 7*I[3, 3, 3, 3, 3, 3, 4] + W[4, 4, 3, 3, 3, 4]
# W[4, 3, 4, 4, 3, 4] - 2*W[4, 4, 3, 4, 3, 4] + W[4, 4, 4, 3, 3, 4]
# 21*I[3, 3, 3, 3, 4, 4, 4] + 2*W[4, 3, 4, 4, 4, 4] + W[4, 4, 4, 4, 3, 4]
# 563335*I[3, 3, 3, 3, 3, 4, 4]/4155984 - 9631*I[3, 3, 3, 3, 4, 4, 3]/109368 - 6004615*I[3, 3, 3]*I[3, 4]/2077992 - 50*I[3, 3, 4, 3, 3, 3, 4]/217 + 60*I[3, 3, 4, 3, 3, 4, 3]/217 - 30*I[3, 3, 4, 3, 4, 3, 3]/217 + 3*I[3, 3, 4, 3]*I[3]/2 + 40*I[3, 3, 4, 4, 3, 3, 3]/1519 - 6*I[3, 3, 4]*I[3, 3] + I[3, 3]*I[3, 4, 3] - 205*I[3, 4, 3, 3, 3, 3, 4]/5208 + 61*I[3, 4, 3, 3, 3, 4, 3]/434 - 71*I[3, 4, 3, 3, 4, 3, 3]/434 - I[3, 4, 3, 3]*I[3]/4 + 55*I[3, 4, 3, 4, 3, 3, 3]/651 - 405*I[3, 4, 4, 3, 3, 3, 3]/24304 - 1215*I[3]**3/434 + 2445*I[3]*W[4, 4, 4]/12152 + 685*W[4, 3, 3, 4, 4, 4]/197904 + 65615*W[4, 4, 3, 4, 3, 4]/1531152 - 55485*W[4, 4, 4, 3, 3, 4]/923552 + 5039*W[4, 4, 4, 4, 3, 3]/461776 + 41*W[6, 4, 4, 4]/104160

# %%
# # Weight 5
syz0=7*I[3, 3, 3] + W[4, 4]

# # Weight 7
syz1=14*I[3, 3, 3, 3, 4] - 7*I[3, 3, 3, 4, 3] + W[4, 3, 4, 4]

# # Weight 8
syz2=-7*I[3, 3, 3, 3, 4, 4] + 14*I[3, 3, 3, 4, 3, 4] - 7*I[3, 3, 3, 4, 4, 3]
syz3=7*I[3, 3, 3, 3, 4, 3] - 7*I[3, 3, 3, 4, 3, 3]/2 - 16*I[3, 4]*W[4]/3 - W[4, 3, 3, 4, 4]/2 + W[4, 3, 4, 3, 4]
syz4=-28*I[3, 3, 3, 3, 3, 3]/5 - 96*I[3, 3]*W[4]/5 - 12*I[3]*W[4, 3]/5 - 7*W[4, 3, 3, 3, 4]/30 + W[4, 3, 3, 4, 3] - 3*W[4, 3, 4, 3, 3]/2 + 49*W[6, 3, 4]/1650 - 14*W[6, 4, 3]/275


syz_ds_dict={W[4]:{(4,):-7*I[3,3,3]}}
syz_ds_dict[W[4]][(3,4,4)]=solve(ds_subs(syz1,syz_ds_dict,D),W[4,3,4,4])[0]
syz_ds_dict[I[3]]={(3,3,4,4,3):solve(ds_subs(syz2,syz_ds_dict,D),I[3,3,3,4,4,3])[0]}
syz_ds_dict[W[4]][(3,4,3,4)]=solve(ds_subs(syz3,syz_ds_dict,D),W[4,3,4,3,4])[0]
syz_ds_dict[W[6]]={(4,3):solve(ds_subs(syz4,syz_ds_dict,D),W[6,4,3])[0]}

# %%
for w in Syzygies:
    print('\nWEIGHT', w)
    for s in Syzygies[w]:
        temp=ds_subs(s,syz_ds_dict,D)
        if temp!=0: print(temp)
# Out:
# WEIGHT 3
#
# WEIGHT 4
#
# WEIGHT 5
#
# WEIGHT 6
#
# WEIGHT 7
#
# WEIGHT 8
#
# WEIGHT 9
# 1288*I[3, 3, 3, 3, 3, 4, 4]/513 - 56*I[3, 3, 3, 3, 4, 3, 4]/27 + 280*I[3, 3, 3, 3, 4, 4, 3]/513 - 28*I[3, 3, 3, 4, 3, 3, 4]/19 + 56*I[3, 3, 3, 4, 3, 4, 3]/57 - 2912*I[3, 3, 3]*I[3, 4]/513 + 16*I[3, 4, 4]*W[4]/3 + 4*W[4, 3, 3, 4, 4, 4]/57
# 7*I[3, 3, 3, 3, 3, 3, 4]/3 - 56*I[3, 3, 3]*I[3, 3] + 8*I[3, 3, 4]*W[4] + I[3, 4]*W[4, 3] + I[3]*W[4, 3, 4] + 7*W[4, 3, 3, 3, 4, 4]/72 - 5*W[4, 3, 3, 4, 3, 4]/12 + 5*W[4, 3, 4, 3, 3, 4]/8 - 7*W[6, 3, 4, 4]/3960 + 7*W[6, 4, 4, 3]/660
# 563335*I[3, 3, 3, 3, 3, 4, 4]/4155984 - 65615*I[3, 3, 3, 3, 4, 3, 4]/218736 - 48521*I[3, 3, 3, 3, 4, 4, 3]/4155984 + 55485*I[3, 3, 3, 4, 3, 3, 4]/131936 - 5039*I[3, 3, 3, 4, 3, 4, 3]/32984 - 2445*I[3, 3, 3, 4]*I[3]/1736 - 6004615*I[3, 3, 3]*I[3, 4]/2077992 - 50*I[3, 3, 4, 3, 3, 3, 4]/217 + 60*I[3, 3, 4, 3, 3, 4, 3]/217 - 30*I[3, 3, 4, 3, 4, 3, 3]/217 + 3*I[3, 3, 4, 3]*I[3]/2 + 40*I[3, 3, 4, 4, 3, 3, 3]/1519 - 6*I[3, 3, 4]*I[3, 3] + I[3, 3]*I[3, 4, 3] - 205*I[3, 4, 3, 3, 3, 3, 4]/5208 + 61*I[3, 4, 3, 3, 3, 4, 3]/434 - 71*I[3, 4, 3, 3, 4, 3, 3]/434 - I[3, 4, 3, 3]*I[3]/4 + 55*I[3, 4, 3, 4, 3, 3, 3]/651 - 405*I[3, 4, 4, 3, 3, 3, 3]/24304 - 1215*I[3]**3/434 + 685*W[4, 3, 3, 4, 4, 4]/197904 + 41*W[6, 4, 4, 4]/104160

# %%
with shelve.open('Syzygies') as shelf:
    shelf['Standard_norm_Syzygy_spaces']=Syzygy_spaces
    shelf['Standard_norm_Syzygies']=Syzygies

# %% [markdown]
# #### Checking Syzygies

# %%
syz0_check=7*higher_der(K3h_coeff,3,3)+higher_der(K4h_coeff,4)
syz1_check=14*higher_der(K3h_coeff,3,3,3,4)-7*higher_der(K3h_coeff,3,3,4,3)+higher_der(K4h_coeff,3,4,4)
syz2_check=-7*higher_der(K3h_coeff,3,3,3,4,4)+14*higher_der(K3h_coeff,3,3,4,3,4)-7*higher_der(K3h_coeff,3,3,4,4,3)


syz0_check=simplify(ds_subs(syz0_check,D_JS,D))
syz1_check=simplify(ds_subs(syz1_check,D_JS,D))
syz2_check=simplify(ds_subs(syz2_check,D_JS,D))
# Out:
# 0

# %%
for A in [syz0_check,syz1_check,syz2_check]:
    if A!=0: print('Failure:', A)

# %%
def check_equivar(c):
    p_inv=-exp(-2*h)*y*Y-h*H-e*E
    c_0=c.subs({y:0,h:0,e:0})
    r=p_inv.Ad(c_0,mod='CE')-c
    simplify_cochain(r)
    if r==C.elt({}): return True
    else: return r

# %%
# Checking equivariance in lower weights
K60=K6.subs({y:0,h:0,e:0})
Z=g.second_kind_inv(P.yhe_pt).Ad(K60)-K6
for i in range(1,7):
    print(simplify(Z.wght_proj(i).symb_expr()))
